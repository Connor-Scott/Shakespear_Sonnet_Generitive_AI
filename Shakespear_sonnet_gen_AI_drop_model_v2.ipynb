# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.callbacks import LambdaCallback
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding, Bidirectional, LSTM

# %matplotlib inline

# %% [markdown]
# ## Adjusted toolkit code

# %%
class DataCleaningToolkit:
    def __init__(self):
        self.sequences = None
        self.next_char = None
        self.n_features = None
        self.unique_chars = None
        self.maxlen = None
        self.char_int = None
        self.int_char = None

    def clean_data(self, doc):
        date_regex = r"\d+/\d+/\d+"
        punct_regex = r"[^0-9a-zA-Z\s]"
        special_chars_regex = r"[\$\%\&\@\n+]"
        numerical_regex = r"\d+"
        multiple_whitespace = " {2,}"

        doc = re.sub(date_regex, "", doc)
        doc = re.sub(special_chars_regex, " ", doc)
        doc = re.sub(numerical_regex, "", doc)
        doc = re.sub(multiple_whitespace, "", doc)

        return doc.lower()

    def create_char_sequences(self, data, maxlen=20, step=5):
        self.maxlen = maxlen
        text = " ".join(data)
        self.unique_chars = list(set(text))
        self.n_features = len(self.unique_chars)
        self.char_int = {c: i for i, c in enumerate(self.unique_chars)}
        self.int_char = {i: c for i, c in enumerate(self.unique_chars)}
        encoded = [self.char_int[char] for char in text]
        total_num_chars_in_text = len(encoded)
        sequences = []
        next_char = []

        for i in range(0, total_num_chars_in_text - maxlen, step):
            sequences.append(encoded[i: i + maxlen])
            next_char.append(encoded[i + maxlen])

        print('Created {0} sequences.'.format(len(sequences)))

        self.sequences = sequences
        self.next_char = next_char

    def create_X_and_Y(self):
        n_seqs = len(self.sequences)
        n_unique_chars = len(self.unique_chars)
        x_dims = (len(self.sequences), self.maxlen, len(self.unique_chars))
        y_dims = (len(self.sequences), len(self.unique_chars))
        x = np.zeros(x_dims, dtype=bool)
        y = np.zeros(y_dims, dtype=bool)

        for i, sequence in enumerate(self.sequences):
            for t, char in enumerate(sequence):
                x[i, t, char] = 1
            y[i, self.next_char[i]] = 1

        return x, y

# %%
import requests

# download all Shakespeare Sonnets from Project Gutenberg
url = "https://www.gutenberg.org/cache/epub/1041/pg1041.txt"
response = requests.get(url)
data = response.text

# %%
# extract the downloaded text from the requests object and save it to `raw_text_data`
raw_text_data = data
# verify data type of `raw_text_data`
assert isinstance(raw_text_data, str)

# %% [markdown]
# ### Data Cleaning

# %%
# inspect data
print(raw_text_data[:3000])
# Out:
# "\ufeffThe Project Gutenberg eBook of Shakespeare's Sonnets\r\n    \r\nThis ebook is for the use of anyone anywhere in the United States and\r\nmost other parts of the world at no cost and with almost no restrictions\r\nwhatsoever. You may copy it, give it away or re-use it under the terms\r\nof the Project Gutenberg License included with this ebook or online\r\nat www.gutenberg.org. If you are not located in the United States,\r\nyou will have to check the laws of the country where you are located\r\nbefore using this eBook.\r\n\r\nTitle: Shakespeare's Sonnets\r\n\r\nAuthor: William Shakespeare\r\n\r\nRelease date: September 1, 1997 [eBook #1041]\r\n                Most recently updated: March 10, 2024\r\n\r\nLanguage: English\r\n\r\nCredits: the Project Gutenberg Shakespeare Team\r\n\r\n\r\n*** START OF THE PROJECT GUTENBERG EBOOK SHAKESPEARE'S SONNETS ***\r\nTHE SONNETS\r\n\r\nby William Shakespeare\r\n\r\n\r\n\r\n\r\nI\r\n\r\nFrom fairest creatures we desire increase,\r\nThat thereby beauty’s rose might never die,\r\nBut as the riper should by time decease,\r\nHis tender heir might bear his memory:\r\nBut thou, contracted to thine own bright eyes,\r\nFeed’st thy light’s flame with self-substantial fuel,\r\nMaking a famine where abundance lies,\r\nThyself thy foe, to thy sweet self too cruel:\r\nThou that art now the world’s fresh ornament,\r\nAnd only herald to the gaudy spring,\r\nWithin thine own bud buriest thy content,\r\nAnd tender churl mak’st waste in niggarding:\r\n    Pity the world, or else this glutton be,\r\n    To eat the world’s due, by the grave and thee.\r\n\r\nII\r\n\r\nWhen forty winters shall besiege thy brow,\r\nAnd dig deep trenches in thy beauty’s field,\r\nThy youth’s proud livery so gazed on now,\r\nWill be a tatter’d weed of small worth held:\r\nThen being asked, where all thy beauty lies,\r\nWhere all the treasure of thy lusty days;\r\nTo say, within thine own deep sunken eyes,\r\nWere an all-eating shame, and thriftless praise.\r\nHow much more praise deserv’d thy beauty’s use,\r\nIf thou couldst answer ‘This fair child of mine\r\nShall sum my count, and make my old excuse,’\r\nProving his beauty by succession thine!\r\n    This were to be new made when thou art old,\r\n    And see thy blood warm when thou feel’st it cold.\r\n\r\nIII\r\n\r\nLook in thy glass and tell the face thou viewest\r\nNow is the time that face should form another;\r\nWhose fresh repair if now thou not renewest,\r\nThou dost beguile the world, unbless some mother.\r\nFor where is she so fair whose unear’d womb\r\nDisdains the tillage of thy husbandry?\r\nOr who is he so fond will be the tomb,\r\nOf his self-love to stop posterity?\r\nThou art thy mother’s glass and she in thee\r\nCalls back the lovely April of her prime;\r\nSo thou through windows of thine age shalt see,\r\nDespite of wrinkles this thy golden time.\r\n    But if thou live, remember’d not to be,\r\n    Die single and thine image dies with thee.\r\n\r\nIV\r\n\r\nUnthrifty loveliness, why dost thou spend\r\nUpon thyself thy beauty’s legacy?\r\nNature’s bequest gives nothing, but doth lend,\r\nAnd being frank she lends to those are free:\r\nThen, beauteous "

# %%
# split the text into lines and save the result to `split_data`
split_data = raw_text_data.split('\r\n')

# %%
# Drop all the boilerplate text (titles and descriptions) as well as extra white spaces
# so that we are left with only the sonnets themselves
split_data = [line for line in split_data if line.strip()]

# Drop the text by index
for i, line in enumerate(split_data):
    if 'by William Shakespeare' in line:
        split_data = split_data[i:]
        break

print(split_data[:80])
# Out:
# ['by William Shakespeare', 'I', 'From fairest creatures we desire increase,', 'That thereby beauty’s rose might never die,', 'But as the riper should by time decease,', 'His tender heir might bear his memory:', 'But thou, contracted to thine own bright eyes,', 'Feed’st thy light’s flame with self-substantial fuel,', 'Making a famine where abundance lies,', 'Thyself thy foe, to thy sweet self too cruel:', 'Thou that art now the world’s fresh ornament,', 'And only herald to the gaudy spring,', 'Within thine own bud buriest thy content,', 'And tender churl mak’st waste in niggarding:', '    Pity the world, or else this glutton be,', '    To eat the world’s due, by the grave and thee.', 'II', 'When forty winters shall besiege thy brow,', 'And dig deep trenches in thy beauty’s field,', 'Thy youth’s proud livery so gazed on now,', 'Will be a tatter’d weed of small worth held:', 'Then being asked, where all thy beauty lies,', 'Where all the treasure of thy lusty days;', 'To say, within thine own deep sunken eyes,', 'Were an all-eating shame, and thriftless praise.', 'How much more praise deserv’d thy beauty’s use,', 'If thou couldst answer ‘This fair child of mine', 'Shall sum my count, and make my old excuse,’', 'Proving his beauty by succession thine!', '    This were to be new made when thou art old,', '    And see thy blood warm when thou feel’st it cold.', 'III', 'Look in thy glass and tell the face thou viewest', 'Now is the time that face should form another;', 'Whose fresh repair if now thou not renewest,', 'Thou dost beguile the world, unbless some mother.', 'For where is she so fair whose unear’d womb', 'Disdains the tillage of thy husbandry?', 'Or who is he so fond will be the tomb,', 'Of his self-love to stop posterity?', 'Thou art thy mother’s glass and she in thee', 'Calls back the lovely April of her prime;', 'So thou through windows of thine age shalt see,', 'Despite of wrinkles this thy golden time.', '    But if thou live, remember’d not to be,', '    Die single and thine image dies with thee.', 'IV', 'Unthrifty loveliness, why dost thou spend', 'Upon thyself thy beauty’s legacy?', 'Nature’s bequest gives nothing, but doth lend,', 'And being frank she lends to those are free:', 'Then, beauteous niggard, why dost thou abuse', 'The bounteous largess given thee to give?', 'Profitless usurer, why dost thou use', 'So great a sum of sums, yet canst not live?', 'For having traffic with thyself alone,', 'Thou of thyself thy sweet self dost deceive:', 'Then how when nature calls thee to be gone,', 'What acceptable audit canst thou leave?', '    Thy unused beauty must be tombed with thee,', '    Which, used, lives th’ executor to be.', 'V', 'Those hours, that with gentle work did frame', 'The lovely gaze where every eye doth dwell,', 'Will play the tyrants to the very same', 'And that unfair which fairly doth excel;', 'For never-resting time leads summer on', 'To hideous winter, and confounds him there;', 'Sap checked with frost, and lusty leaves quite gone,', 'Beauty o’er-snowed and bareness every where:', 'Then were not summer’s distillation left,', 'A liquid prisoner pent in walls of glass,', 'Beauty’s effect with beauty were bereft,', 'Nor it, nor no remembrance what it was:', '    But flowers distill’d, though they with winter meet,', '    Leese but their show; their substance still lives sweet.', 'VI', 'Then let not winter’s ragged hand deface,', 'In thee thy summer, ere thou be distill’d:', 'Make sweet some vial; treasure thou some place', 'With beauty’s treasure ere it be self-kill’d.', 'That use is not forbidden usury,', 'Which happies those that pay the willing loan;', 'That’s for thyself to breed another thee,', 'Or ten times happier, be it ten for one;', 'Ten times thyself were happier than thou art,', 'If ten of thine ten times refigur’d thee:', 'Then what could death do if thou shouldst depart,', 'Leaving thee living in posterity?', '    Be not self-will’d, for thou art much too fair', '    To be death’s conques ...
# ['by William Shakespeare',
#  'I',
#  'From fairest creatures we desire increase,',
#  'That thereby beauty’s rose might never die,',
#  'But as the riper should by time decease,',
#  'His tender heir might bear his memory:',
#  'But thou, contracted to thine own bright eyes,',
#  'Feed’st thy light’s flame with self-substantial fuel,',
#  'Making a famine where abundance lies,',
#  'Thyself thy foe, to thy sweet self too cruel:',
#  'Thou that art now the world’s fresh ornament,',
#  'And only herald to the gaudy spring,',
#  'Within thine own bud buriest thy content,',
#  'And tender churl mak’st waste in niggarding:',
#  '    Pity the world, or else this glutton be,',
#  '    To eat the world’s due, by the grave and thee.',
#  'II',
#  'When forty winters shall besiege thy brow,',
#  'And dig deep trenches in thy beauty’s field,',
#  'Thy youth’s proud livery so gazed on now,',
#  'Will be a tatter’d weed of small worth held:',
#  'Then being asked, where all thy beauty lies,',
#  'Where all the treasure of thy lusty days;',
#  'To say, within thine own deep sunken eyes,',
#  'Were an all-eating shame, and thriftless praise.',
#  'How much more praise deserv’d thy beauty’s use,',
#  'If thou couldst answer ‘This fair child of mine',
#  'Shall sum my count, and make my old excuse,’',
#  'Proving his beauty by succession thine!',
#  '    This were to be new made when thou art old,',
#  '    And see thy blood warm when thou feel’st it cold.',
#  'III',
#  'Look in thy glass and tell the face thou viewest',
#  'Now is the time that face should form another;',
#  'Whose fresh repair if now thou not renewest,',
#  'Thou dost beguile the world, unbless some mother.',
#  'For where is she so fair whose unear’d womb',
#  'Disdains the tillage of thy husbandry?',
#  'Or who is he so fond will be the tomb,',
#  'Of his self-love to stop posterity?',
#  'Thou art thy mother’s glass and she in thee',
#  'Calls back the lovely April of her prime;',
#  'So thou through windows of thine age shalt see,',
#  'Despite of wrinkles this thy golden time.',
#  '    But if thou live, remember’d not to be,',
#  '    Die single and thine image dies with thee.',
#  'IV',
#  'Unthrifty loveliness, why dost thou spend',
#  'Upon thyself thy beauty’s legacy?',
#  'Nature’s bequest gives nothing, but doth lend,',
#  'And being frank she lends to those are free:',
#  'Then, beauteous niggard, why dost thou abuse',
#  'The bounteous largess given thee to give?',
#  'Profitless usurer, why dost thou use',
#  'So great a sum of sums, yet canst not live?',
#  'For having traffic with thyself alone,',
#  'Thou of thyself thy sweet self dost deceive:',
#  'Then how when nature calls thee to be gone,',
#  'What acceptable audit canst thou leave?',
#  '    Thy unused beauty must be tombed with thee,',
#  '    Which, used, lives th’ executor to be.',
#  'V',
#  'Those hours, that with gentle work did frame',
#  'The lovely gaze where every eye doth dwell,',
#  'Will play the tyrants to the very same',
#  'And that unfair which fairly doth excel;',
#  'For never-resting time leads summer on',
#  'To hideous winter, and confounds him there;',
#  'Sap checked with frost, and lusty leaves quite gone,',
#  'Beauty o’er-snowed and bareness every where:',
#  'Then were not summer’s distillation left,',
#  'A liquid prisoner pent in walls of glass,',
#  'Beauty’s effect with beauty were bereft,',
#  'Nor it, nor no remembrance what it was:',
#  '    But flowers distill’d, though they with winter meet,',
#  '    Leese but their show; their substance still lives sweet.',
#  'VI',
#  'Then let not winter’s ragged hand deface,',
#  'In thee thy summer, ere thou be distill’d:',
#  'Make sweet some vial; treasure thou some place']

# %%
split_data = [line for line in split_data if 'by William Shakespeare' not in line]

# %%
print(split_data[:10])
# Out:
# ['I',
#  'From fairest creatures we desire increase,',
#  'That thereby beauty’s rose might never die,',
#  'But as the riper should by time decease,',
#  'His tender heir might bear his memory:',
#  'But thou, contracted to thine own bright eyes,',
#  'Feed’st thy light’s flame with self-substantial fuel,',
#  'Making a famine where abundance lies,',
#  'Thyself thy foe, to thy sweet self too cruel:',
#  'Thou that art now the world’s fresh ornament,']

# %%
sonnets = [line for line in split_data if 'by William Shakespeare' not in line]

# %%
sonnets = [line for line in sonnets if len(line) > 10]
sonnets[200:240]
# Out:
# ['Nor can I fortune to brief minutes tell,',
#  'Pointing to each his thunder, rain and wind,',
#  'Or say with princes if it shall go well',
#  'By oft predict that I in heaven find:',
#  'But from thine eyes my knowledge I derive,',
#  'And constant stars in them I read such art',
#  'As ‘Truth and beauty shall together thrive,',
#  'If from thyself, to store thou wouldst convert’;',
#  '    Or else of thee this I prognosticate:',
#  '    ‘Thy end is truth’s and beauty’s doom and date.’',
#  'XV',
#  'When I consider everything that grows',
#  'Holds in perfection but a little moment,',
#  'That this huge stage presenteth nought but shows',
#  'Whereon the stars in secret influence comment;',
#  'When I perceive that men as plants increase,',
#  'Cheered and checked even by the self-same sky,',
#  'Vaunt in their youthful sap, at height decrease,',
#  'And wear their brave state out of memory;',
#  'Then the conceit of this inconstant stay',
#  'Sets you most rich in youth before my sight,',
#  'Where wasteful Time debateth with Decay',
#  'To change your day of youth to sullied night,',
#  '    And all in war with Time for love of you,',
#  '    As he takes from you, I engraft you new.',
#  'XVI',
#  'But wherefore do not you a mightier way',
#  'Make war upon this bloody tyrant, Time?',
#  'And fortify yourself in your decay',
#  'With means more blessed than my barren rhyme?',
#  'Now stand you on the top of happy hours,',
#  'And many maiden gardens, yet unset,',
#  'With virtuous wish would bear you living flowers,',
#  'Much liker than your painted counterfeit:',
#  'So should the lines of life that life repair,',
#  'Which this, Time’s pencil, or my pupil pen,',
#  'Neither in inward worth nor outward fair,',
#  'Can make you live yourself in eyes of men.',
#  '    To give away yourself, keeps yourself still,',
#  '    And you must live, drawn by your own sweet skill.']

# %%
n_chars = 20
filtered_sonnets = [line.strip() for line in sonnets if len(line) > n_chars]

# %%
filtered_sonnets[:20]
# Out:
# ['From fairest creatures we desire increase,',
#  'That thereby beauty’s rose might never die,',
#  'But as the riper should by time decease,',
#  'His tender heir might bear his memory:',
#  'But thou, contracted to thine own bright eyes,',
#  'Feed’st thy light’s flame with self-substantial fuel,',
#  'Making a famine where abundance lies,',
#  'Thyself thy foe, to thy sweet self too cruel:',
#  'Thou that art now the world’s fresh ornament,',
#  'And only herald to the gaudy spring,',
#  'Within thine own bud buriest thy content,',
#  'And tender churl mak’st waste in niggarding:',
#  'Pity the world, or else this glutton be,',
#  'To eat the world’s due, by the grave and thee.',
#  'When forty winters shall besiege thy brow,',
#  'And dig deep trenches in thy beauty’s field,',
#  'Thy youth’s proud livery so gazed on now,',
#  'Will be a tatter’d weed of small worth held:',
#  'Then being asked, where all thy beauty lies,',
#  'Where all the treasure of thy lusty days;']

# %% [markdown]
# ### Use Custom Data Cleaning Tool
#
# using one of the methods in the `data_cleaning_toolkit` from Bloom teach to clean your data.

# %%
# Instantiating the DataCleaningToolkit class and saving it to dctk
dctk = DataCleaningToolkit()

# %%
clean_sonnets = filtered_sonnets

# %%
print(clean_sonnets)
print(len(clean_sonnets[:10]))
# Out:
# ['From fairest creatures we desire increase,',
#  'That thereby beauty’s rose might never die,',
#  'But as the riper should by time decease,',
#  'His tender heir might bear his memory:',
#  'But thou, contracted to thine own bright eyes,',
#  'Feed’st thy light’s flame with self-substantial fuel,',
#  'Making a famine where abundance lies,',
#  'Thyself thy foe, to thy sweet self too cruel:',
#  'Thou that art now the world’s fresh ornament,',
#  'And only herald to the gaudy spring,',
#  'Within thine own bud buriest thy content,',
#  'And tender churl mak’st waste in niggarding:',
#  'Pity the world, or else this glutton be,',
#  'To eat the world’s due, by the grave and thee.',
#  'When forty winters shall besiege thy brow,',
#  'And dig deep trenches in thy beauty’s field,',
#  'Thy youth’s proud livery so gazed on now,',
#  'Will be a tatter’d weed of small worth held:',
#  'Then being asked, where all thy beauty lies,',
#  'Where all the treasure of thy lusty days;',
#  'To say, within thine own deep sunken eyes,',
#  'Were an all-eating shame, and thriftless praise.',
#  'How much more praise deserv’d thy beauty’s use,',
#  'If thou couldst answer ‘This fair child of mine',
#  'Shall sum my count, and make my old excuse,’',
#  'Proving his beauty by succession thine!',
#  'This were to be new made when thou art old,',
#  'And see thy blood warm when thou feel’st it cold.',
#  'Look in thy glass and tell the face thou viewest',
#  'Now is the time that face should form another;',
#  'Whose fresh repair if now thou not renewest,',
#  'Thou dost beguile the world, unbless some mother.',
#  'For where is she so fair whose unear’d womb',
#  'Disdains the tillage of thy husbandry?',
#  'Or who is he so fond will be the tomb,',
#  'Of his self-love to stop posterity?',
#  'Thou art thy mother’s glass and she in thee',
#  'Calls back the lovely April of her prime;',
#  'So thou through windows of thine age shalt see,',
#  'Despite of wrinkles this thy golden time.',
#  'But if thou live, remember’d not to be,',
#  'Die single and thine image dies with thee.',
#  'Unthrifty loveliness, why dost thou spend',
#  'Upon thyself thy beauty’s legacy?',
#  'Nature’s bequest gives nothing, but doth lend,',
#  'And being frank she lends to those are free:',
#  'Then, beauteous niggard, why dost thou abuse',
#  'The bounteous largess given thee to give?',
#  'Profitless usurer, why dost thou use',
#  'So great a sum of sums, yet canst not live?',
#  'For having traffic with thyself alone,',
#  'Thou of thyself thy sweet self dost deceive:',
#  'Then how when nature calls thee to be gone,',
#  'What acceptable audit canst thou leave?',
#  'Thy unused beauty must be tombed with thee,',
#  'Which, used, lives th’ executor to be.',
#  'Those hours, that with gentle work did frame',
#  'The lovely gaze where every eye doth dwell,',
#  'Will play the tyrants to the very same',
#  'And that unfair which fairly doth excel;',
#  'For never-resting time leads summer on',
#  'To hideous winter, and confounds him there;',
#  'Sap checked with frost, and lusty leaves quite gone,',
#  'Beauty o’er-snowed and bareness every where:',
#  'Then were not summer’s distillation left,',
#  'A liquid prisoner pent in walls of glass,',
#  'Beauty’s effect with beauty were bereft,',
#  'Nor it, nor no remembrance what it was:',
#  'But flowers distill’d, though they with winter meet,',
#  'Leese but their show; their substance still lives sweet.',
#  'Then let not winter’s ragged hand deface,',
#  'In thee thy summer, ere thou be distill’d:',
#  'Make sweet some vial; treasure thou some place',
#  'With beauty’s treasure ere it be self-kill’d.',
#  'That use is not forbidden usury,',
#  'Which happies those that pay the willing loan;',
#  'That’s for thyself to breed another thee,',
#  'Or ten times happier, be it ten for one;',
#  'Ten times thyself were happier than thou art,',
#  'If ten of thine ten times refigur’d thee:',
#  'Then what could death do if thou shouldst depart,',
#  'Leaving thee living in posterity?',
#  'Be not self-will’d, for thou art much too fair',
#  'To be death’s conquest and make worms thine heir.',
#  'Lo! in the orient when the gracious light',
#  'Lifts up his burning head, each under eye',
#  'Doth homage to his new-appearing sight,',
#  'Serving with looks his sacred majesty;',
#  'And having climb’d the steep-up heavenly hill,',
#  'Resembling strong youth in his middle age,',
#  'Yet mortal looks adore his beauty still,',
#  'Attending on his golden pilgrimage:',
#  'But when from highmost pitch, with weary car,',
#  'Like feeble age, he reeleth from the day,',
#  'The eyes, ’fore duteous, now converted are',
#  'From his low tract, and look another way:',
#  'So thou, thyself outgoing in thy noon:',
#  'Unlook’d, on diest unless thou get a son.',
#  'Music to hear, why hear’st thou music sadly?',
#  'Sweets with sweets war not, joy delights in joy:',
#  'Why lov’st thou that which thou receiv’st not gladly,',
#  'Or else receiv’st with pleasure thine annoy?',
#  'If the true concord of well-tuned sounds,',
#  'By unions married, do offend thine ear,',
#  'They do but sweetly chide thee, who confounds',
#  'In singleness the parts that thou shouldst bear.',
#  'Mark how one string, sweet husband to another,',
#  'Strikes each in each by mutual ordering;',
#  'Resembling sire and child and happy mother,',
#  'Who, all in one, one pleasing note do sing:',
#  'Whose speechless song being many, seeming one,',
#  'Sings this to thee: ‘Thou single wilt prove none.’',
#  'Is it for fear to wet a widow’s eye,',
#  'That thou consum’st thyself in single life?',
#  'Ah! if thou issueless shalt hap to die,',
#  'The world will wail thee like a makeless wife;',
#  'The world will be thy widow and still weep',
#  'That thou no form of thee hast left behind,',
#  'When every private widow well may keep',
#  'By children’s eyes, her husband’s shape in mind:',
#  'Look! what an unthrift in the world doth spend',
#  'Shifts but his place, for still the world enjoys it;',
#  'But beauty’s waste hath in the world an end,',
#  'And kept unused the user so destroys it.',
#  'No love toward others in that bosom sits',
#  'That on himself such murd’rous shame commits.',
#  'For shame! deny that thou bear’st love to any,',
#  'Who for thyself art so unprovident.',
#  'Grant, if thou wilt, thou art belov’d of many,',
#  'But that thou none lov’st is most evident:',
#  'For thou art so possess’d with murderous hate,',
#  'That ’gainst thyself thou stick’st not to conspire,',
#  'Seeking that beauteous roof to ruinate',
#  'Which to repair should be thy chief desire.',
#  'O! change thy thought, that I may change my mind:',
#  'Shall hate be fairer lodg’d than gentle love?',
#  'Be, as thy presence is, gracious and kind,',
#  'Or to thyself at least kind-hearted prove:',
#  'Make thee another self for love of me,',
#  'That beauty still may live in thine or thee.',
#  'As fast as thou shalt wane, so fast thou grow’st,',
#  'In one of thine, from that which thou departest;',
#  'And that fresh blood which youngly thou bestow’st,',
#  'Thou mayst call thine when thou from youth convertest,',
#  'Herein lives wisdom, beauty, and increase;',
#  'Without this folly, age, and cold decay:',
#  'If all were minded so, the times should cease',
#  'And threescore year would make the world away.',
#  'Let those whom nature hath not made for store,',
#  'Harsh, featureless, and rude, barrenly perish:',
#  'Look, whom she best endow’d, she gave thee more;',
#  'Which bounteous gift thou shouldst in bounty cherish:',
#  'She carv’d thee for her seal, and meant thereby,',
#  'Thou shouldst print more, not let that copy die.',
#  'When I do count the clock that tells the time,',
#  'And see the brave day sunk in hideous night;',
#  'When I behold the violet past prime,',
#  'And sable curls, all silvered o’er with white;',
#  'When lofty trees I see barren of leaves,',
#  'Which erst from heat did canopy the herd,',
#  'And summer’s green all girded up in sheaves,',
#  'Borne on the bier with white and bristly beard,',
#  'Then of thy beauty do I question make,',
#  'That thou among the wastes of time must go,',
#  'Since sweets and beauties do themselves forsake',
#  'And die as fast as they see others grow;',
#  'And nothing ’gainst Time’s scythe can make defence',
#  'Save breed, to brave him when he takes thee hence.',
#  'O! that you were your self; but, love you are',
#  'No longer yours, than you yourself here live:',
#  'Against this coming end you should prepare,',
#  'And your sweet semblance to some other give:',
#  'So should that beauty which you hold in lease',
#  'Find no determination; then you were',
#  'Yourself again, after yourself’s decease,',
#  'When your sweet issue your sweet form should bear.',
#  'Who lets so fair a house fall to decay,',
#  'Which husbandry in honour might uphold,',
#  'Against the stormy gusts of winter’s day',
#  'And barren rage of death’s eternal cold?',
#  'O! none but unthrifts. Dear my love, you know,',
#  'You had a father: let your son say so.',
#  'Not from the stars do I my judgement pluck;',
#  'And yet methinks I have astronomy,',
#  'But not to tell of good or evil luck,',
#  'Of plagues, of dearths, or seasons’ quality;',
#  'Nor can I fortune to brief minutes tell,',
#  'Pointing to each his thunder, rain and wind,',
#  'Or say with princes if it shall go well',
#  'By oft predict that I in heaven find:',
#  'But from thine eyes my knowledge I derive,',
#  'And constant stars in them I read such art',
#  'As ‘Truth and beauty shall together thrive,',
#  'If from thyself, to store thou wouldst convert’;',
#  'Or else of thee this I prognosticate:',
#  '‘Thy end is truth’s and beauty’s doom and date.’',
#  'When I consider everything that grows',
#  'Holds in perfection but a little moment,',
#  'That this huge stage presenteth nought but shows',
#  'Whereon the stars in secret influence comment;',
#  'When I perceive that men as plants increase,',
#  'Cheered and checked even by the self-same sky,',
#  'Vaunt in their youthful sap, at height decrease,',
#  'And wear their brave state out of memory;',
#  'Then the conceit of this inconstant stay',
#  'Sets you most rich in youth before my sight,',
#  'Where wasteful Time debateth with Decay',
#  'To change your day of youth to sullied night,',
#  'And all in war with Time for love of you,',
#  'As he takes from you, I engraft you new.',
#  'But wherefore do not you a mightier way',
#  'Make war upon this bloody tyrant, Time?',
#  'And fortify yourself in your decay',
#  'With means more blessed than my barren rhyme?',
#  'Now stand you on the top of happy hours,',
#  'And many maiden gardens, yet unset,',
#  'With virtuous wish would bear you living flowers,',
#  'Much liker than your painted counterfeit:',
#  'So should the lines of life that life repair,',
#  'Which this, Time’s pencil, or my pupil pen,',
#  'Neither in inward worth nor outward fair,',
#  'Can make you live yourself in eyes of men.',
#  'To give away yourself, keeps yourself still,',
#  'And you must live, drawn by your own sweet skill.',
#  'Who will believe my verse in time to come,',
#  'If it were fill’d with your most high deserts?',
#  'Though yet heaven knows it is but as a tomb',
#  'Which hides your life, and shows not half your parts.',
#  'If I could write the beauty of your eyes,',
#  'And in fresh numbers number all your graces,',
#  'The age to come would say ‘This poet lies;',
#  'Such heavenly touches ne’er touch’d earthly faces.’',
#  'So should my papers, yellow’d with their age,',
#  'Be scorn’d, like old men of less truth than tongue,',
#  'And your true rights be term’d a poet’s rage',
#  'And stretched metre of an antique song:',
#  'But were some child of yours alive that time,',
#  'You should live twice,—in it, and in my rhyme.',
#  'Shall I compare thee to a summer’s day?',
#  'Thou art more lovely and more temperate:',
#  'Rough winds do shake the darling buds of May,',
#  'And summer’s lease hath all too short a date:',
#  'Sometime too hot the eye of heaven shines,',
#  'And often is his gold complexion dimm’d,',
#  'And every fair from fair sometime declines,',
#  'By chance, or nature’s changing course untrimm’d:',
#  'But thy eternal summer shall not fade,',
#  'Nor lose possession of that fair thou ow’st,',
#  'Nor shall death brag thou wander’st in his shade,',
#  'When in eternal lines to time thou grow’st,',
#  'So long as men can breathe, or eyes can see,',
#  'So long lives this, and this gives life to thee.',
#  'Devouring Time, blunt thou the lion’s paws,',
#  'And make the earth devour her own sweet brood;',
#  'Pluck the keen teeth from the fierce tiger’s jaws,',
#  'And burn the long-liv’d phoenix, in her blood;',
#  'Make glad and sorry seasons as thou fleets,',
#  'And do whate’er thou wilt, swift-footed Time,',
#  'To the wide world and all her fading sweets;',
#  'But I forbid thee one most heinous crime:',
#  'O! carve not with thy hours my love’s fair brow,',
#  'Nor draw no lines there with thine antique pen;',
#  'Him in thy course untainted do allow',
#  'For beauty’s pattern to succeeding men.',
#  'Yet do thy worst, old Time; despite thy wrong,',
#  'My love shall in my verse ever live young.',
#  'A woman’s face with nature’s own hand painted,',
#  'Hast thou, the master mistress of my passion;',
#  'A woman’s gentle heart, but not acquainted',
#  'With shifting change, as is false women’s fashion:',
#  'An eye more bright than theirs, less false in rolling,',
#  'Gilding the object whereupon it gazeth;',
#  'A man in hue all ‘hues’ in his controlling,',
#  'Which steals men’s eyes and women’s souls amazeth.',
#  'And for a woman wert thou first created;',
#  'Till Nature, as she wrought thee, fell a-doting,',
#  'And by addition me of thee defeated,',
#  'By adding one thing to my purpose nothing.',
#  'But since she prick’d thee out for women’s pleasure,',
#  'Mine be thy love and thy love’s use their treasure.',
#  'So is it not with me as with that Muse,',
#  'Stirr’d by a painted beauty to his verse,',
#  'Who heaven itself for ornament doth use',
#  'And every fair with his fair doth rehearse,',
#  'Making a couplement of proud compare.',
#  'With sun and moon, with earth and sea’s rich gems,',
#  'With April’s first-born flowers, and all things rare,',
#  'That heaven’s air in this huge rondure hems.',
#  'O! let me, true in love, but truly write,',
#  'And then believe me, my love is as fair',
#  'As any mother’s child, though not so bright',
#  'As those gold candles fix’d in heaven’s air:',
#  'Let them say more that like of hearsay well;',
#  'I will not praise that purpose not to sell.',
#  'My glass shall not persuade me I am old,',
#  'So long as youth and thou are of one date;',
#  'But when in thee time’s furrows I behold,',
#  'Then look I death my days should expiate.',
#  'For all that beauty that doth cover thee,',
#  'Is but the seemly raiment of my heart,',
#  'Which in thy breast doth live, as thine in me:',
#  'How can I then be elder than thou art?',
#  'O! therefore love, be of thyself so wary',
#  'As I, not for myself, but for thee will;',
#  'Bearing thy heart, which I will keep so chary',
#  'As tender nurse her babe from faring ill.',
#  'Presume not on thy heart when mine is slain,',
#  'Thou gav’st me thine not to give back again.',
#  'As an unperfect actor on the stage,',
#  'Who with his fear is put beside his part,',
#  'Or some fierce thing replete with too much rage,',
#  'Whose strength’s abundance weakens his own heart;',
#  'So I, for fear of trust, forget to say',
#  'The perfect ceremony of love’s rite,',
#  'And in mine own love’s strength seem to decay,',
#  'O’ercharg’d with burthen of mine own love’s might.',
#  'O! let my looks be then the eloquence',
#  'And dumb presagers of my speaking breast,',
#  'Who plead for love, and look for recompense,',
#  'More than that tongue that more hath more express’d.',
#  'O! learn to read what silent love hath writ:',
#  'To hear with eyes belongs to love’s fine wit.',
#  'Mine eye hath play’d the painter and hath stell’d,',
#  'Thy beauty’s form in table of my heart;',
#  'My body is the frame wherein ’tis held,',
#  'And perspective it is best painter’s art.',
#  'For through the painter must you see his skill,',
#  'To find where your true image pictur’d lies,',
#  'Which in my bosom’s shop is hanging still,',
#  'That hath his windows glazed with thine eyes.',
#  'Now see what good turns eyes for eyes have done:',
#  'Mine eyes have drawn thy shape, and thine for me',
#  'Are windows to my breast, where-through the sun',
#  'Delights to peep, to gaze therein on thee;',
#  'Yet eyes this cunning want to grace their art,',
#  'They draw but what they see, know not the heart.',
#  'Let those who are in favour with their stars',
#  'Of public honour and proud titles boast,',
#  'Whilst I, whom fortune of such triumph bars',
#  'Unlook’d for joy in that I honour most.',
#  'Great princes’ favourites their fair leaves spread',
#  'But as the marigold at the sun’s eye,',
#  'And in themselves their pride lies buried,',
#  'For at a frown they in their glory die.',
#  'The painful warrior famoused for fight,',
#  'After a thousand victories once foil’d,',
#  'Is from the book of honour razed quite,',
#  'And all the rest forgot for which he toil’d:',
#  'Then happy I, that love and am belov’d,',
#  'Where I may not remove nor be remov’d.',
#  'Lord of my love, to whom in vassalage',
#  'Thy merit hath my duty strongly knit,',
#  'To thee I send this written embassage,',
#  'To witness duty, not to show my wit:',
#  'Duty so great, which wit so poor as mine',
#  'May make seem bare, in wanting words to show it,',
#  'But that I hope some good conceit of thine',
#  'In thy soul’s thought, all naked, will bestow it:',
#  'Till whatsoever star that guides my moving,',
#  'Points on me graciously with fair aspect,',
#  'And puts apparel on my tatter’d loving,',
#  'To show me worthy of thy sweet respect:',
#  'Then may I dare to boast how I do love thee;',
#  'Till then, not show my head where thou mayst prove me.',
#  'Weary with toil, I haste me to my bed,',
#  'The dear respose for limbs with travel tir’d;',
#  'But then begins a journey in my head',
#  'To work my mind, when body’s work’s expired:',
#  'For then my thoughts, from far where I abide,',
#  'Intend a zealous pilgrimage to thee,',
#  'And keep my drooping eyelids open wide,',
#  'Looking on darkness which the blind do see:',
#  'Save that my soul’s imaginary sight',
#  'Presents thy shadow to my sightless view,',
#  'Which, like a jewel hung in ghastly night,',
#  'Makes black night beauteous, and her old face new.',
#  'Lo! thus, by day my limbs, by night my mind,',
#  'For thee, and for myself, no quiet find.',
#  'How can I then return in happy plight,',
#  'That am debarre’d the benefit of rest?',
#  'When day’s oppression is not eas’d by night,',
#  'But day by night and night by day oppress’d,',
#  'And each, though enemies to either’s reign,',
#  'Do in consent shake hands to torture me,',
#  'The one by toil, the other to complain',
#  'How far I toil, still farther off from thee.',
#  'I tell the day, to please him thou art bright,',
#  'And dost him grace when clouds do blot the heaven:',
#  'So flatter I the swart-complexion’d night,',
#  'When sparkling stars twire not thou gild’st the even.',
#  'But day doth daily draw my sorrows longer,',
#  'And night doth nightly make grief’s length seem stronger.',
#  'When in disgrace with fortune and men’s eyes',
#  'I all alone beweep my outcast state,',
#  'And trouble deaf heaven with my bootless cries,',
#  'And look upon myself, and curse my fate,',
#  'Wishing me like to one more rich in hope,',
#  'Featur’d like him, like him with friends possess’d,',
#  'Desiring this man’s art, and that man’s scope,',
#  'With what I most enjoy contented least;',
#  'Yet in these thoughts my self almost despising,',
#  'Haply I think on thee, and then my state,',
#  'Like to the lark at break of day arising',
#  'From sullen earth, sings hymns at heaven’s gate;',
#  'For thy sweet love remember’d such wealth brings',
#  'That then I scorn to change my state with kings.',
#  'When to the sessions of sweet silent thought',
#  'I summon up remembrance of things past,',
#  'I sigh the lack of many a thing I sought,',
#  'And with old woes new wail my dear time’s waste:',
#  'Then can I drown an eye, unused to flow,',
#  'For precious friends hid in death’s dateless night,',
#  'And weep afresh love’s long since cancell’d woe,',
#  'And moan the expense of many a vanish’d sight:',
#  'Then can I grieve at grievances foregone,',
#  'And heavily from woe to woe tell o’er',
#  'The sad account of fore-bemoaned moan,',
#  'Which I new pay as if not paid before.',
#  'But if the while I think on thee, dear friend,',
#  'All losses are restor’d and sorrows end.',
#  'Thy bosom is endeared with all hearts,',
#  'Which I by lacking have supposed dead;',
#  'And there reigns Love, and all Love’s loving parts,',
#  'And all those friends which I thought buried.',
#  'How many a holy and obsequious tear',
#  'Hath dear religious love stol’n from mine eye,',
#  'As interest of the dead, which now appear',
#  'But things remov’d that hidden in thee lie!',
#  'Thou art the grave where buried love doth live,',
#  'Hung with the trophies of my lovers gone,',
#  'Who all their parts of me to thee did give,',
#  'That due of many now is thine alone:',
#  'Their images I lov’d, I view in thee,',
#  'And thou, all they, hast all the all of me.',
#  'If thou survive my well-contented day,',
#  'When that churl Death my bones with dust shall cover',
#  'And shalt by fortune once more re-survey',
#  'These poor rude lines of thy deceased lover,',
#  'Compare them with the bett’ring of the time,',
#  'And though they be outstripp’d by every pen,',
#  'Reserve them for my love, not for their rhyme,',
#  'Exceeded by the height of happier men.',
#  'O! then vouchsafe me but this loving thought:',
#  '‘Had my friend’s Muse grown with this growing age,',
#  'A dearer birth than this his love had brought,',
#  'To march in ranks of better equipage:',
#  'But since he died and poets better prove,',
#  'Theirs for their style I’ll read, his for his love’.',
#  'Full many a glorious morning have I seen',
#  'Flatter the mountain tops with sovereign eye,',
#  'Kissing with golden face the meadows green,',
#  'Gilding pale streams with heavenly alchemy;',
#  'Anon permit the basest clouds to ride',
#  'With ugly rack on his celestial face,',
#  'And from the forlorn world his visage hide,',
#  'Stealing unseen to west with this disgrace:',
#  'Even so my sun one early morn did shine,',
#  'With all triumphant splendour on my brow;',
#  'But out! alack! he was but one hour mine,',
#  'The region cloud hath mask’d him from me now.',
#  'Yet him for this my love no whit disdaineth;',
#  'Suns of the world may stain when heaven’s sun staineth.',
#  'Why didst thou promise such a beauteous day,',
#  'And make me travel forth without my cloak,',
#  'To let base clouds o’ertake me in my way,',
#  'Hiding thy bravery in their rotten smoke?',
#  '’Tis not enough that through the cloud thou break,',
#  'To dry the rain on my storm-beaten face,',
#  'For no man well of such a salve can speak,',
#  'That heals the wound, and cures not the disgrace:',
#  'Nor can thy shame give physic to my grief;',
#  'Though thou repent, yet I have still the loss:',
#  'The offender’s sorrow lends but weak relief',
#  'To him that bears the strong offence’s cross.',
#  'Ah! but those tears are pearl which thy love sheds,',
#  'And they are rich and ransom all ill deeds.',
#  'No more be griev’d at that which thou hast done:',
#  'Roses have thorns, and silver fountains mud:',
#  'Clouds and eclipses stain both moon and sun,',
#  'And loathsome canker lives in sweetest bud.',
#  'All men make faults, and even I in this,',
#  'Authorizing thy trespass with compare,',
#  'Myself corrupting, salving thy amiss,',
#  'Excusing thy sins more than thy sins are;',
#  'For to thy sensual fault I bring in sense;',
#  'Thy adverse party is thy advocate,',
#  'And ’gainst myself a lawful plea commence:',
#  'Such civil war is in my love and hate,',
#  'That I an accessary needs must be,',
#  'To that sweet thief which sourly robs from me.',
#  'Let me confess that we two must be twain,',
#  'Although our undivided loves are one:',
#  'So shall those blots that do with me remain,',
#  'Without thy help, by me be borne alone.',
#  'In our two loves there is but one respect,',
#  'Though in our lives a separable spite,',
#  'Which though it alter not love’s sole effect,',
#  'Yet doth it steal sweet hours from love’s delight.',
#  'I may not evermore acknowledge thee,',
#  'Lest my bewailed guilt should do thee shame,',
#  'Nor thou with public kindness honour me,',
#  'Unless thou take that honour from thy name:',
#  'But do not so, I love thee in such sort,',
#  'As thou being mine, mine is thy good report.',
#  'As a decrepit father takes delight',
#  'To see his active child do deeds of youth,',
#  'So I, made lame by Fortune’s dearest spite,',
#  'Take all my comfort of thy worth and truth;',
#  'For whether beauty, birth, or wealth, or wit,',
#  'Or any of these all, or all, or more,',
#  'Entitled in thy parts, do crowned sit,',
#  'I make my love engrafted, to this store:',
#  'So then I am not lame, poor, nor despis’d,',
#  'Whilst that this shadow doth such substance give',
#  'That I in thy abundance am suffic’d,',
#  'And by a part of all thy glory live.',
#  'Look what is best, that best I wish in thee:',
#  'This wish I have; then ten times happy me!',
#  'How can my Muse want subject to invent,',
#  'While thou dost breathe, that pour’st into my verse',
#  'Thine own sweet argument, too excellent',
#  'For every vulgar paper to rehearse?',
#  'O! give thyself the thanks, if aught in me',
#  'Worthy perusal stand against thy sight;',
#  'For who’s so dumb that cannot write to thee,',
#  'When thou thyself dost give invention light?',
#  'Be thou the tenth Muse, ten times more in worth',
#  'Than those old nine which rhymers invocate;',
#  'And he that calls on thee, let him bring forth',
#  'Eternal numbers to outlive long date.',
#  'If my slight Muse do please these curious days,',
#  'The pain be mine, but thine shall be the praise.',
#  'O! how thy worth with manners may I sing,',
#  'When thou art all the better part of me?',
#  'What can mine own praise to mine own self bring?',
#  'And what is’t but mine own when I praise thee?',
#  'Even for this, let us divided live,',
#  'And our dear love lose name of single one,',
#  'That by this separation I may give',
#  'That due to thee which thou deserv’st alone.',
#  'O absence! what a torment wouldst thou prove,',
#  'Were it not thy sour leisure gave sweet leave,',
#  'To entertain the time with thoughts of love,',
#  'Which time and thoughts so sweetly doth deceive,',
#  'And that thou teachest how to make one twain,',
#  'By praising him here who doth hence remain.',
#  'Take all my loves, my love, yea take them all;',
#  'What hast thou then more than thou hadst before?',
#  'No love, my love, that thou mayst true love call;',
#  'All mine was thine, before thou hadst this more.',
#  'Then, if for my love, thou my love receivest,',
#  'I cannot blame thee, for my love thou usest;',
#  'But yet be blam’d, if thou thyself deceivest',
#  'By wilful taste of what thyself refusest.',
#  'I do forgive thy robbery, gentle thief,',
#  'Although thou steal thee all my poverty:',
#  'And yet, love knows it is a greater grief',
#  'To bear love’s wrong, than hate’s known injury.',
#  'Lascivious grace, in whom all ill well shows,',
#  'Kill me with spites yet we must not be foes.',
#  'Those pretty wrongs that liberty commits,',
#  'When I am sometime absent from thy heart,',
#  'Thy beauty, and thy years full well befits,',
#  'For still temptation follows where thou art.',
#  'Gentle thou art, and therefore to be won,',
#  'Beauteous thou art, therefore to be assail’d;',
#  'And when a woman woos, what woman’s son',
#  'Will sourly leave her till he have prevail’d?',
#  'Ay me! but yet thou mightst my seat forbear,',
#  'And chide thy beauty and thy straying youth,',
#  'Who lead thee in their riot even there',
#  'Where thou art forced to break a twofold truth:',
#  'Hers by thy beauty tempting her to thee,',
#  'Thine by thy beauty being false to me.',
#  'That thou hast her it is not all my grief,',
#  'And yet it may be said I loved her dearly;',
#  'That she hath thee is of my wailing chief,',
#  'A loss in love that touches me more nearly.',
#  'Loving offenders thus I will excuse ye:',
#  'Thou dost love her, because thou know’st I love her;',
#  'And for my sake even so doth she abuse me,',
#  'Suffering my friend for my sake to approve her.',
#  'If I lose thee, my loss is my love’s gain,',
#  'And losing her, my friend hath found that loss;',
#  'Both find each other, and I lose both twain,',
#  'And both for my sake lay on me this cross:',
#  'But here’s the joy; my friend and I are one;',
#  'Sweet flattery! then she loves but me alone.',
#  'When most I wink, then do mine eyes best see,',
#  'For all the day they view things unrespected;',
#  'But when I sleep, in dreams they look on thee,',
#  'And darkly bright, are bright in dark directed.',
#  'Then thou, whose shadow shadows doth make bright,',
#  'How would thy shadow’s form form happy show',
#  'To the clear day with thy much clearer light,',
#  'When to unseeing eyes thy shade shines so!',
#  'How would, I say, mine eyes be blessed made',
#  'By looking on thee in the living day,',
#  'When in dead night thy fair imperfect shade',
#  'Through heavy sleep on sightless eyes doth stay!',
#  'All days are nights to see till I see thee,',
#  'And nights bright days when dreams do show thee me.',
#  'If the dull substance of my flesh were thought,',
#  'Injurious distance should not stop my way;',
#  'For then despite of space I would be brought,',
#  'From limits far remote, where thou dost stay.',
#  'No matter then although my foot did stand',
#  'Upon the farthest earth remov’d from thee;',
#  'For nimble thought can jump both sea and land,',
#  'As soon as think the place where he would be.',
#  'But, ah! thought kills me that I am not thought,',
#  'To leap large lengths of miles when thou art gone,',
#  'But that so much of earth and water wrought,',
#  'I must attend time’s leisure with my moan;',
#  'Receiving nought by elements so slow',
#  'But heavy tears, badges of either’s woe.',
#  'The other two, slight air, and purging fire',
#  'Are both with thee, wherever I abide;',
#  'The first my thought, the other my desire,',
#  'These present-absent with swift motion slide.',
#  'For when these quicker elements are gone',
#  'In tender embassy of love to thee,',
#  'My life, being made of four, with two alone',
#  'Sinks down to death, oppress’d with melancholy;',
#  'Until life’s composition be recur’d',
#  'By those swift messengers return’d from thee,',
#  'Who even but now come back again, assur’d,',
#  'Of thy fair health, recounting it to me:',
#  'This told, I joy; but then no longer glad,',
#  'I send them back again, and straight grow sad.',
#  'Mine eye and heart are at a mortal war,',
#  'How to divide the conquest of thy sight;',
#  'Mine eye my heart thy picture’s sight would bar,',
#  'My heart mine eye the freedom of that right.',
#  'My heart doth plead that thou in him dost lie,',
#  'A closet never pierced with crystal eyes;',
#  'But the defendant doth that plea deny,',
#  'And says in him thy fair appearance lies.',
#  'To side this title is impannelled',
#  'A quest of thoughts, all tenants to the heart;',
#  'And by their verdict is determined',
#  'The clear eye’s moiety, and the dear heart’s part:',
#  'As thus; mine eye’s due is thy outward part,',
#  'And my heart’s right, thy inward love of heart.',
#  'Betwixt mine eye and heart a league is took,',
#  'And each doth good turns now unto the other:',
#  'When that mine eye is famish’d for a look,',
#  'Or heart in love with sighs himself doth smother,',
#  'With my love’s picture then my eye doth feast,',
#  'And to the painted banquet bids my heart;',
#  'Another time mine eye is my heart’s guest,',
#  'And in his thoughts of love doth share a part:',
#  'So, either by thy picture or my love,',
#  'Thyself away, art present still with me;',
#  'For thou not farther than my thoughts canst move,',
#  'And I am still with them, and they with thee;',
#  'Or, if they sleep, thy picture in my sight',
#  'Awakes my heart, to heart’s and eye’s delight.',
#  'How careful was I when I took my way,',
#  'Each trifle under truest bars to thrust,',
#  'That to my use it might unused stay',
#  'From hands of falsehood, in sure wards of trust!',
#  'But thou, to whom my jewels trifles are,',
#  'Most worthy comfort, now my greatest grief,',
#  'Thou best of dearest, and mine only care,',
#  'Art left the prey of every vulgar thief.',
#  'Thee have I not lock’d up in any chest,',
#  'Save where thou art not, though I feel thou art,',
#  'Within the gentle closure of my breast,',
#  'From whence at pleasure thou mayst come and part;',
#  'And even thence thou wilt be stol’n I fear,',
#  'For truth proves thievish for a prize so dear.',
#  'Against that time, if ever that time come,',
#  'When I shall see thee frown on my defects,',
#  'When as thy love hath cast his utmost sum,',
#  'Call’d to that audit by advis’d respects;',
#  'Against that time when thou shalt strangely pass,',
#  'And scarcely greet me with that sun, thine eye,',
#  'When love, converted from the thing it was,',
#  'Shall reasons find of settled gravity;',
#  'Against that time do I ensconce me here,',
#  'Within the knowledge of mine own desert,',
#  'And this my hand, against my self uprear,',
#  'To guard the lawful reasons on thy part:',
#  'To leave poor me thou hast the strength of laws,',
#  'Since why to love I can allege no cause.',
#  'How heavy do I journey on the way,',
#  'When what I seek, my weary travel’s end,',
#  'Doth teach that ease and that repose to say,',
#  '‘Thus far the miles are measured from thy friend!’',
#  'The beast that bears me, tired with my woe,',
#  'Plods dully on, to bear that weight in me,',
#  'As if by some instinct the wretch did know',
#  'His rider lov’d not speed, being made from thee:',
#  'The bloody spur cannot provoke him on,',
#  'That sometimes anger thrusts into his hide,',
#  'Which heavily he answers with a groan,',
#  'More sharp to me than spurring to his side;',
#  'For that same groan doth put this in my mind,',
#  'My grief lies onward, and my joy behind.',
#  'Thus can my love excuse the slow offence',
#  'Of my dull bearer when from thee I speed:',
#  'From where thou art why should I haste me thence?',
#  'Till I return, of posting is no need.',
#  'O! what excuse will my poor beast then find,',
#  'When swift extremity can seem but slow?',
#  'Then should I spur, though mounted on the wind,',
#  'In winged speed no motion shall I know,',
#  'Then can no horse with my desire keep pace;',
#  'Therefore desire, of perfect’st love being made,',
#  'Shall neigh no dull flesh in his fiery race,',
#  'But love, for love, thus shall excuse my jade:',
#  '‘Since from thee going, he went wilful-slow,',
#  'Towards thee I’ll run, and give him leave to go.’',
#  'So am I as the rich, whose blessed key,',
#  'Can bring him to his sweet up-locked treasure,',
#  'The which he will not every hour survey,',
#  'For blunting the fine point of seldom pleasure.',
#  'Therefore are feasts so solemn and so rare,',
#  'Since, seldom coming in that long year set,',
#  'Like stones of worth they thinly placed are,',
#  'Or captain jewels in the carcanet.',
#  'So is the time that keeps you as my chest,',
#  'Or as the wardrobe which the robe doth hide,',
#  'To make some special instant special-blest,',
#  'By new unfolding his imprison’d pride.',
#  'Blessed are you whose worthiness gives scope,',
#  'Being had, to triumph; being lacked, to hope.',
#  'What is your substance, whereof are you made,',
#  'That millions of strange shadows on you tend?',
#  'Since every one, hath every one, one shade,',
#  'And you but one, can every shadow lend.',
#  'Describe Adonis, and the counterfeit',
#  'Is poorly imitated after you;',
#  'On Helen’s cheek all art of beauty set,',
#  'And you in Grecian tires are painted new:',
#  'Speak of the spring, and foison of the year,',
#  'The one doth shadow of your beauty show,',
#  'The other as your bounty doth appear;',
#  'And you in every blessed shape we know.',
#  'In all external grace you have some part,',
#  'But you like none, none you, for constant heart.',
#  'O! how much more doth beauty beauteous seem',
#  'By that sweet ornament which truth doth give.',
#  'The rose looks fair, but fairer we it deem',
#  'For that sweet odour, which doth in it live.',
#  'The canker blooms have full as deep a dye',
#  'As the perfumed tincture of the roses.',
#  'Hang on such thorns, and play as wantonly',
#  'When summer’s breath their masked buds discloses:',
#  'But, for their virtue only is their show,',
#  'They live unwoo’d, and unrespected fade;',
#  'Die to themselves. Sweet roses do not so;',
#  'Of their sweet deaths, are sweetest odours made:',
#  'And so of you, beauteous and lovely youth,',
#  'When that shall vade, by verse distills your truth.',
#  'Not marble, nor the gilded monuments',
#  'Of princes, shall outlive this powerful rhyme;',
#  'But you shall shine more bright in these contents',
#  'Than unswept stone, besmear’d with sluttish time.',
#  'When wasteful war shall statues overturn,',
#  'And broils root out the work of masonry,',
#  'Nor Mars his sword, nor war’s quick fire shall burn',
#  'The living record of your memory.',
#  '’Gainst death, and all-oblivious enmity',
#  'Shall you pace forth; your praise shall still find room',
#  'Even in the eyes of all posterity',
#  'That wear this world out to the ending doom.',
#  'So, till the judgement that yourself arise,',
#  'You live in this, and dwell in lovers’ eyes.',
#  'Sweet love, renew thy force; be it not said',
#  'Thy edge should blunter be than appetite,',
#  'Which but to-day by feeding is allay’d,',
#  'To-morrow sharpened in his former might:',
#  'So, love, be thou, although to-day thou fill',
#  'Thy hungry eyes, even till they wink with fulness,',
#  'To-morrow see again, and do not kill',
#  'The spirit of love, with a perpetual dulness.',
#  'Let this sad interim like the ocean be',
#  'Which parts the shore, where two contracted new',
#  'Come daily to the banks, that when they see',
#  'Return of love, more blest may be the view;',
#  'Or call it winter, which being full of care,',
#  'Makes summer’s welcome, thrice more wished, more rare.',
#  'Being your slave what should I do but tend,',
#  'Upon the hours, and times of your desire?',
#  'I have no precious time at all to spend;',
#  'Nor services to do, till you require.',
#  'Nor dare I chide the world-without-end hour,',
#  'Whilst I, my sovereign, watch the clock for you,',
#  'Nor think the bitterness of absence sour,',
#  'When you have bid your servant once adieu;',
#  'Nor dare I question with my jealous thought',
#  'Where you may be, or your affairs suppose,',
#  'But, like a sad slave, stay and think of nought',
#  'Save, where you are, how happy you make those.',
#  'So true a fool is love, that in your will,',
#  'Though you do anything, he thinks no ill.',
#  'That god forbid, that made me first your slave,',
#  'I should in thought control your times of pleasure,',
#  'Or at your hand the account of hours to crave,',
#  'Being your vassal, bound to stay your leisure!',
#  'O! let me suffer, being at your beck,',
#  'The imprison’d absence of your liberty;',
#  'And patience, tame to sufferance, bide each check,',
#  'Without accusing you of injury.',
#  'Be where you list, your charter is so strong',
#  'That you yourself may privilage your time',
#  'To what you will; to you it doth belong',
#  'Yourself to pardon of self-doing crime.',
#  'I am to wait, though waiting so be hell,',
#  'Not blame your pleasure be it ill or well.',
#  'If there be nothing new, but that which is',
#  'Hath been before, how are our brains beguil’d,',
#  'Which labouring for invention bear amiss',
#  'The second burthen of a former child!',
#  'O! that record could with a backward look,',
#  'Even of five hundred courses of the sun,',
#  'Show me your image in some antique book,',
#  'Since mind at first in character was done!',
#  'That I might see what the old world could say',
#  'To this composed wonder of your frame;',
#  'Wh’r we are mended, or wh’r better they,',
#  'Or whether revolution be the same.',
#  'O! sure I am the wits of former days,',
#  'To subjects worse have given admiring praise.',
#  'Like as the waves make towards the pebbled shore,',
#  'So do our minutes hasten to their end;',
#  'Each changing place with that which goes before,',
#  'In sequent toil all forwards do contend.',
#  'Nativity, once in the main of light,',
#  'Crawls to maturity, wherewith being crown’d,',
#  'Crooked eclipses ’gainst his glory fight,',
#  'And Time that gave doth now his gift confound.',
#  'Time doth transfix the flourish set on youth',
#  'And delves the parallels in beauty’s brow,',
#  'Feeds on the rarities of nature’s truth,',
#  'And nothing stands but for his scythe to mow:',
#  'And yet to times in hope, my verse shall stand.',
#  'Praising thy worth, despite his cruel hand.',
#  'Is it thy will, thy image should keep open',
#  'My heavy eyelids to the weary night?',
#  'Dost thou desire my slumbers should be broken,',
#  'While shadows like to thee do mock my sight?',
#  'Is it thy spirit that thou send’st from thee',
#  'So far from home into my deeds to pry,',
#  'To find out shames and idle hours in me,',
#  'The scope and tenure of thy jealousy?',
#  'O, no! thy love, though much, is not so great:',
#  'It is my love that keeps mine eye awake:',
#  'Mine own true love that doth my rest defeat,',
#  'To play the watchman ever for thy sake:',
#  'For thee watch I, whilst thou dost wake elsewhere,',
#  'From me far off, with others all too near.',
#  'Sin of self-love possesseth all mine eye',
#  'And all my soul, and all my every part;',
#  'And for this sin there is no remedy,',
#  'It is so grounded inward in my heart.',
#  'Methinks no face so gracious is as mine,',
#  'No shape so true, no truth of such account;',
#  'And for myself mine own worth do define,',
#  'As I all other in all worths surmount.',
#  'But when my glass shows me myself indeed',
#  'Beated and chopp’d with tanned antiquity,',
#  'Mine own self-love quite contrary I read;',
#  'Self so self-loving were iniquity.',
#  '’Tis thee, myself, that for myself I praise,',
#  'Painting my age with beauty of thy days.',
#  'Against my love shall be as I am now,',
#  'With Time’s injurious hand crush’d and o’erworn;',
#  'When hours have drain’d his blood and fill’d his brow',
#  'With lines and wrinkles; when his youthful morn',
#  'Hath travell’d on to age’s steepy night;',
#  'And all those beauties whereof now he’s king',
#  'Are vanishing, or vanished out of sight,',
#  'Stealing away the treasure of his spring;',
#  'For such a time do I now fortify',
#  'Against confounding age’s cruel knife,',
#  'That he shall never cut from memory',
#  'My sweet love’s beauty, though my lover’s life:',
#  'His beauty shall in these black lines be seen,',
#  'And they shall live, and he in them still green.',
#  'When I have seen by Time’s fell hand defac’d',
#  'The rich-proud cost of outworn buried age;',
#  'When sometime lofty towers I see down-raz’d,',
#  'And brass eternal slave to mortal rage;',
#  'When I have seen the hungry ocean gain',
#  'Advantage on the kingdom of the shore,',
#  'And the firm soil win of the watery main,',
#  'Increasing store with loss, and loss with store;',
#  'When I have seen such interchange of state,',
#  'Or state itself confounded, to decay;',
#  'Ruin hath taught me thus to ruminate:',
#  'That Time will come and take my love away.',
#  'This thought is as a death which cannot choose',
#  'But weep to have, that which it fears to lose.',
#  'Since brass, nor stone, nor earth, nor boundless sea,',
#  'But sad mortality o’ersways their power,',
#  'How with this rage shall beauty hold a plea,',
#  'Whose action is no stronger than a flower?',
#  'O! how shall summer’s honey breath hold out,',
#  'Against the wrackful siege of battering days,',
#  'When rocks impregnable are not so stout,',
#  'Nor gates of steel so strong but Time decays?',
#  'O fearful meditation! where, alack,',
#  'Shall Time’s best jewel from Time’s chest lie hid?',
#  'Or what strong hand can hold his swift foot back?',
#  'Or who his spoil of beauty can forbid?',
#  'O! none, unless this miracle have might,',
#  'That in black ink my love may still shine bright.',
#  'Tired with all these, for restful death I cry:',
#  'As to behold desert a beggar born,',
#  'And needy nothing trimm’d in jollity,',
#  'And purest faith unhappily forsworn,',
#  'And gilded honour shamefully misplac’d,',
#  'And maiden virtue rudely strumpeted,',
#  'And right perfection wrongfully disgrac’d,',
#  'And strength by limping sway disabled',
#  'And art made tongue-tied by authority,',
#  'And folly, doctor-like, controlling skill,',
#  'And simple truth miscall’d simplicity,',
#  'And captive good attending captain ill:',
#  'Tir’d with all these, from these would I be gone,',
#  'Save that, to die, I leave my love alone.',
#  'Ah! wherefore with infection should he live,',
#  'And with his presence grace impiety,',
#  'That sin by him advantage should achieve,',
#  'And lace itself with his society?',
#  'Why should false painting imitate his cheek,',
#  'And steel dead seeming of his living hue?',
#  'Why should poor beauty indirectly seek',
#  'Roses of shadow, since his rose is true?',
#  'Why should he live, now Nature bankrupt is,',
#  'Beggar’d of blood to blush through lively veins?',
#  'For she hath no exchequer now but his,',
#  'And proud of many, lives upon his gains.',
#  'O! him she stores, to show what wealth she had',
#  'In days long since, before these last so bad.',
#  'Thus is his cheek the map of days outworn,',
#  'When beauty lived and died as flowers do now,',
#  'Before these bastard signs of fair were born,',
#  'Or durst inhabit on a living brow;',
#  'Before the golden tresses of the dead,',
#  'The right of sepulchres, were shorn away,',
#  'To live a second life on second head;',
#  'Ere beauty’s dead fleece made another gay:',
#  'In him those holy antique hours are seen,',
#  'Without all ornament, itself and true,',
#  'Making no summer of another’s green,',
#  'Robbing no old to dress his beauty new;',
#  'And him as for a map doth Nature store,',
#  'To show false Art what beauty was of yore.',
#  'Those parts of thee that the world’s eye doth view',
#  'Want nothing that the thought of hearts can mend;',
#  'All tongues, the voice of souls, give thee that due,',
#  'Uttering bare truth, even so as foes commend.',
#  'Thy outward thus with outward praise is crown’d;',
#  'But those same tongues, that give thee so thine own,',
#  'In other accents do this praise confound',
#  'By seeing farther than the eye hath shown.',
#  'They look into the beauty of thy mind,',
#  'And that in guess they measure by thy deeds;',
#  'Then churls their thoughts, although their eyes were kind,',
#  'To thy fair flower add the rank smell of weeds:',
#  'But why thy odour matcheth not thy show,',
#  'The soil is this, that thou dost common grow.',
#  'That thou art blam’d shall not be thy defect,',
#  'For slander’s mark was ever yet the fair;',
#  'The ornament of beauty is suspect,',
#  'A crow that flies in heaven’s sweetest air.',
#  'So thou be good, slander doth but approve',
#  'Thy worth the greater being woo’d of time;',
#  'For canker vice the sweetest buds doth love,',
#  'And thou present’st a pure unstained prime.',
#  'Thou hast passed by the ambush of young days',
#  'Either not assail’d, or victor being charg’d;',
#  'Yet this thy praise cannot be so thy praise,',
#  'To tie up envy, evermore enlarg’d,',
#  'If some suspect of ill mask’d not thy show,',
#  'Then thou alone kingdoms of hearts shouldst owe.',
#  'No longer mourn for me when I am dead',
#  'Than you shall hear the surly sullen bell',
#  'Give warning to the world that I am fled',
#  'From this vile world with vilest worms to dwell:',
#  'Nay, if you read this line, remember not',
#  'The hand that writ it, for I love you so,',
#  'That I in your sweet thoughts would be forgot,',
#  'If thinking on me then should make you woe.',
#  'O if, I say, you look upon this verse,',
#  'When I perhaps compounded am with clay,',
#  'Do not so much as my poor name rehearse;',
#  'But let your love even with my life decay;',
#  'Lest the wise world should look into your moan,',
#  'And mock you with me after I am gone.',
#  'O! lest the world should task you to recite',
#  'What merit lived in me, that you should love',
#  'After my death, dear love, forget me quite,',
#  'For you in me can nothing worthy prove;',
#  'Unless you would devise some virtuous lie,',
#  'To do more for me than mine own desert,',
#  ...]
# 10

# %%
import numpy as np

def calc_stats(corpus):
    """
    Calculates statistics on the length of every line in the sonnets
    """
    doc_lens = [len(line) for line in corpus]
    return np.mean(doc_lens), np.median(doc_lens), np.std(doc_lens), np.max(doc_lens), np.min(doc_lens)

# %%
# Sonnet line length statistics
mean, median, std, max_len, min_len = calc_stats(clean_sonnets)
mean, median, std, max_len, min_len
# Out:
# (44.89946655724251, 43.0, 8.343477135617167, 78, 20)

# %%
# Using .create_char_sequences() to create sequences
maxlen = 100
dctk.create_char_sequences(clean_sonnets, maxlen)
# Out:
# Created 22352 sequences.

# %% [markdown]
# Take a look at the `data_cleaning_toolkit_class.py` file.
#
# In the first 4 lines of code in the `create_char_sequences` method, class attributes `n_features` and `unique_chars` are created. <br>
# Let's call them in the cells below.

# %%
# Number of input features for our LSTM model
dctk.n_features
# Out:
# 83

# %%
# Unique characters that appear in our sonnets, which will be the features that our model predicts
dctk.unique_chars
# Out:
# ['G',
#  'n',
#  'y',
#  '3',
#  '”',
#  '™',
#  'u',
#  'F',
#  'J',
#  'D',
#  'R',
#  's',
#  ':',
#  'q',
#  ' ',
#  'X',
#  'Y',
#  'z',
#  'S',
#  'W',
#  '‘',
#  '“',
#  'x',
#  'c',
#  '6',
#  'r',
#  '8',
#  'Q',
#  '-',
#  '4',
#  'e',
#  '.',
#  'E',
#  'o',
#  '2',
#  '7',
#  'd',
#  'P',
#  '’',
#  '%',
#  'k',
#  'v',
#  "'",
#  '5',
#  '(',
#  '/',
#  'B',
#  '*',
#  'N',
#  '!',
#  'O',
#  'm',
#  'M',
#  'A',
#  '$',
#  '•',
#  'L',
#  ';',
#  'V',
#  '9',
#  ')',
#  'H',
#  ',',
#  'h',
#  'j',
#  '0',
#  'f',
#  '1',
#  'T',
#  '?',
#  'U',
#  'i',
#  '—',
#  'p',
#  'K',
#  'C',
#  'l',
#  'I',
#  't',
#  'b',
#  'w',
#  'a',
#  'g']

# %% [markdown]
# ----

# %% [markdown]
# ### Use Our Data Tool to Create X and Y Splits
#
# Creating `create_X_and_Y` method to do this

# %%
X, y = dctk.create_X_and_Y()

# %%
# Check the shape of the input array
X.shape
# Out:
# (22352, 100, 83)

# %%
# Return the first sample from the input array
first_sample = X[0]
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
X[first_sample_index].shape
# Out:
# (100, 83)

# %%
# Index for a single character vector
first_char_vect_index = 0
X[first_sample_index, first_char_vect_index]
# Out:
# array([False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %%
dctk.int_char
# Out:
# {0: 'G',
#  1: 'n',
#  2: 'y',
#  3: '3',
#  4: '”',
#  5: '™',
#  6: 'u',
#  7: 'F',
#  8: 'J',
#  9: 'D',
#  10: 'R',
#  11: 's',
#  12: ':',
#  13: 'q',
#  14: ' ',
#  15: 'X',
#  16: 'Y',
#  17: 'z',
#  18: 'S',
#  19: 'W',
#  20: '‘',
#  21: '“',
#  22: 'x',
#  23: 'c',
#  24: '6',
#  25: 'r',
#  26: '8',
#  27: 'Q',
#  28: '-',
#  29: '4',
#  30: 'e',
#  31: '.',
#  32: 'E',
#  33: 'o',
#  34: '2',
#  35: '7',
#  36: 'd',
#  37: 'P',
#  38: '’',
#  39: '%',
#  40: 'k',
#  41: 'v',
#  42: "'",
#  43: '5',
#  44: '(',
#  45: '/',
#  46: 'B',
#  47: '*',
#  48: 'N',
#  49: '!',
#  50: 'O',
#  51: 'm',
#  52: 'M',
#  53: 'A',
#  54: '$',
#  55: '•',
#  56: 'L',
#  57: ';',
#  58: 'V',
#  59: '9',
#  60: ')',
#  61: 'H',
#  62: ',',
#  63: 'h',
#  64: 'j',
#  65: '0',
#  66: 'f',
#  67: '1',
#  68: 'T',
#  69: '?',
#  70: 'U',
#  71: 'i',
#  72: '—',
#  73: 'p',
#  74: 'K',
#  75: 'C',
#  76: 'l',
#  77: 'I',
#  78: 't',
#  79: 'b',
#  80: 'w',
#  81: 'a',
#  82: 'g'}

# %%
seq_len_counter = 0

for seq_of_char_vects in X[first_sample_index]:
    index_with_TRUE_val = np.argmax(seq_of_char_vects)
    print(dctk.int_char[index_with_TRUE_val])
    seq_len_counter += 1

print("Sequence length: {}".format(seq_len_counter))
# Out:
# F
# r
# o
# m
#
# f
# a
# i
# r
# e
# s
# t
#
# c
# r
# e
# a
# t
# u
# r
# e
# s
#
# w
# e
#
# d
# e
# s
# i
# r
# e
#
# i
# n
# c
# r
# e
# a
# s
# e
# ,
#
# T
# h
# a
# t
#
# t
# h
# e
# r
# e
# b
# y
#
# b
# e
# a
# u
# t
# y
# ’
# s
#
# r
# o
# s
# e
#
# m
# i
# g
# h
# t
#
# n
# e
# v
# e
# r
#
# d
# i
# e
# ,
#
# B
# u
# t
#
# a
# s
#
# t
# h
# e
#
# r
# i
# Sequence length: 100

# %% [markdown]
# ----

# %% [markdown]
# ### Building the Shakespeare Sonnet Text Generation Model

# %%
def sample(preds, temperature=0.5, top_k=5):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)

    top_k_idxs = np.argsort(preds)[-top_k:]
    top_k_probs = preds[top_k_idxs]
    top_k_probs /= np.sum(top_k_probs)

    chosen_idx = np.random.choice(top_k_idxs, p=top_k_probs)

    return chosen_idx

# %%
def on_epoch_end(epoch, _):
    """
    Function invoked at the end of each epoch. Prints the text generated by our model.
    """

    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - dctk.maxlen - 1)
    generated = ''
    sentence = text[start_index: start_index + dctk.maxlen]
    generated += sentence

    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)

    for _ in range(dctk.maxlen):
        x_dims = (1, dctk.maxlen, dctk.n_features)
        x_pred = np.zeros(x_dims)

        for t, char in enumerate(sentence):
            x_pred[0, t, dctk.char_int[char]] = 1

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds)
        next_char = dctk.int_char[next_index]

        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()

# %%
# Import necessary libraries

# Calculate total number of characters in the text
text = " ".join(clean_sonnets)
print(f'All of Shakespeare\'s sonnets comprise about {len(text)} characters')
# Out:
# All of Shakespeare's sonnets comprise about 111856 characters

# %%
# Create a callback object that will print out text generation at the end of each epoch
# Use for real-time monitoring of model performance
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional

model = Sequential([
    Bidirectional(LSTM(256, return_sequences=True, input_shape=(dctk.maxlen, dctk.n_features))),
    Dropout(0.2),
    Bidirectional(LSTM(128)),
    Dropout(0.2),
    Dense(dctk.n_features, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(X, y, batch_size=256, epochs=25, callbacks=[print_callback])
# Out:
# Epoch 1/90
# c:\Users\synth\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - loss: 3.4627
# ----- Generating text after Epoch: 0
# ----- Generating with seed: "any gazers mightst thou lead away, If thou wouldst use the strength of all thy state! But do not so;"
# any gazers mightst thou lead away, If thou wouldst use the strength of all thy state! But do not so;i t oet eeete t      t     e  o o     tiet   et e    o ei e   ee   e  ite e  ee  e  ee    e eee  o o
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 460ms/step - loss: 3.4601
# Epoch 2/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - loss: 3.0386
# ----- Generating text after Epoch: 1
# ----- Generating with seed: "thou lov’st me for my name is ‘Will.’ Thou blind fool, Love, what dost thou to mine eyes, That they "
# thou lov’st me for my name is ‘Will.’ Thou blind fool, Love, what dost thou to mine eyes, That they the nen he the the on no th non so to ntr te he ne on nte ntoe no sn heer an an so ot he ote nt no t
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 500ms/step - loss: 3.0379
# Epoch 3/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - loss: 2.7312
# ----- Generating text after Epoch: 2
# ----- Generating with seed: "thou wilt take, Thou usurer, that putt’st forth all to use, And sue a friend came debtor for my sake"
# thou wilt take, Thou usurer, that putt’st forth all to use, And sue a friend came debtor for my sake the are wo t the son as ot the won te ant ore war the as thee the the se than the sath ol thit the
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 45s 508ms/step - loss: 2.7305
# Epoch 4/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - loss: 2.5627
# ----- Generating text after Epoch: 3
# ----- Generating with seed: " And even thence thou wilt be stol’n I fear, For truth proves thievish for a prize so dear. Against "
#  And even thence thou wilt be stol’n I fear, For truth proves thievish for a prize so dear. Against the tho mith thest the thes thar the the shat the the tore se the be thind to sint at the the thor s
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 47s 531ms/step - loss: 2.5623
# Epoch 5/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - loss: 2.4797
# ----- Generating text after Epoch: 4
# ----- Generating with seed: "hful sap, at height decrease, And wear their brave state out of memory; Then the conceit of this inc"
# hful sap, at height decrease, And wear their brave state out of memory; Then the conceit of this incant thang and ther sot the the thy the ath the thin the tor sat sind the the the the ther see thot t
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 50s 572ms/step - loss: 2.4794
# Epoch 6/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - loss: 2.4160
# ----- Generating text after Epoch: 5
# ----- Generating with seed: "But, for their virtue only is their show, They live unwoo’d, and unrespected fade; Die to themselves"
# But, for their virtue only is their show, They live unwoo’d, and unrespected fade; Die to themselves ther the thes sor ther shat ther thand the the mes so dor mind the thes me the the thes thy dor anl
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 50s 566ms/step - loss: 2.4158
# Epoch 7/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - loss: 2.3729
# ----- Generating text after Epoch: 6
# ----- Generating with seed: "ing this eBook. 1.E.2. If an individual Project Gutenberg™ electronic work is derived from texts not"
# ing this eBook. 1.E.2. If an individual Project Gutenberg™ electronic work is derived from texts not the shath se be me bere sith ther the the sit mare the thy mith me sher mour asth the the the thor
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 48s 551ms/step - loss: 2.3728
# Epoch 8/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - loss: 2.3151
# ----- Generating text after Epoch: 7
# ----- Generating with seed: "t take All this away, and me most wretched make. But do thy worst to steal thyself away, For term of"
# t take All this away, and me most wretched make. But do thy worst to steal thyself away, For term of my ther sor that thart wheress wered so there the the wo that whe mour thand the the thane winging
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 50s 564ms/step - loss: 2.3149
# Epoch 9/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 547ms/step - loss: 2.2630
# ----- Generating text after Epoch: 8
# ----- Generating with seed: "ment. There are a few things that you can do with most Project Gutenberg™ electronic works even with"
# ment. There are a few things that you can do with most Project Gutenberg™ electronic works even with the then wher that the ther are then the to then the bith the the that that sall so then so thing,
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 52s 589ms/step - loss: 2.2630
# Epoch 10/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - loss: 2.2155
# ----- Generating text after Epoch: 9
# ----- Generating with seed: "y now is thine alone: Their images I lov’d, I view in thee, And thou, all they, hast all the all of "
# y now is thine alone: Their images I lov’d, I view in thee, And thou, all they, hast all the all of ther that whert that all thore thy ther the mes ald the somes whou so the wore that thou ther and an
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 50s 571ms/step - loss: 2.2155
# Epoch 11/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 2.2113
# ----- Generating text after Epoch: 10
# ----- Generating with seed: "ee; For I have sworn thee fair; more perjured I, To swear against the truth so foul a lie. Cupid lai"
# ee; For I have sworn thee fair; more perjured I, To swear against the truth so foul a lie. Cupid laind and thy the thou the were thou sates with me then butere and thou then wire she wore beart ther t
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 51s 576ms/step - loss: 2.2112
# Epoch 12/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - loss: 2.1403
# ----- Generating text after Epoch: 11
# ----- Generating with seed: "s agreement and help preserve free future access to Project Gutenberg™ electronic works. See paragra"
# s agreement and help preserve free future access to Project Gutenberg™ electronic works. See paragrat mout as ar the mear the thin the meart whee the meate suth thy to wort the then the all and thou t
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 49s 556ms/step - loss: 2.1403
# Epoch 13/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - loss: 2.1201
# ----- Generating text after Epoch: 12
# ----- Generating with seed: " day And barren rage of death’s eternal cold? O! none but unthrifts. Dear my love, you know, You had"
#  day And barren rage of death’s eternal cold? O! none but unthrifts. Dear my love, you know, You had to the mand so shen me the beate of shou deant an tay that thy deard the so thou shy love be sten i
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 48s 552ms/step - loss: 2.1201
# Epoch 14/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - loss: 2.1010
# ----- Generating text after Epoch: 13
# ----- Generating with seed: "nd he that calls on thee, let him bring forth Eternal numbers to outlive long date. If my slight Mus"
# nd he that calls on thee, let him bring forth Eternal numbers to outlive long date. If my slight Muse the thand the thee the then beart the tored on thor the tore se tere the ling the thar the more th
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 49s 554ms/step - loss: 2.1011
# Epoch 15/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - loss: 2.1053
# ----- Generating text after Epoch: 14
# ----- Generating with seed: "r pity is enough to cure me. Your love and pity doth the impression fill, Which vulgar scandal stamp"
# r pity is enough to cure me. Your love and pity doth the impression fill, Which vulgar scandal stamp the thy stire lin and the lof she ther the shall she ther stath thou math sound the ment the shall
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 47s 531ms/step - loss: 2.1052
# Epoch 16/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - loss: 2.0394
# ----- Generating text after Epoch: 15
# ----- Generating with seed: "d cease And threescore year would make the world away. Let those whom nature hath not made for store"
# d cease And threescore year would make the world away. Let those whom nature hath not made for store and the ther thes ther thou the lower ther the loves sune as beatere be ther the my there to thou t
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 45s 516ms/step - loss: 2.0394
# Epoch 17/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - loss: 1.9983
# ----- Generating text after Epoch: 16
# ----- Generating with seed: "ere. You to your beauteous blessings add a curse, Being fond on praise, which makes your praises wor"
# ere. You to your beauteous blessings add a curse, Being fond on praise, which makes your praises wor the tound the will mit will ston the beertion seath the will shat thy thine mained thin this me my
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 505ms/step - loss: 1.9983
# Epoch 18/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - loss: 1.9508
# ----- Generating text after Epoch: 17
# ----- Generating with seed: " NO OTHER WARRANTIES OF ANY KIND, EXPRESS OR IMPLIED, INCLUDING BUT NOT LIMITED TO WARRANTIES OF MER"
#  NO OTHER WARRANTIES OF ANY KIND, EXPRESS OR IMPLIED, INCLUDING BUT NOT LIMITED TO WARRANTIES OF MERERTE ORREES. SOSE OS Gatere The woll the all stail wher thee of the worth wart the prom’s with my do
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 492ms/step - loss: 1.9509
# Epoch 19/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - loss: 1.9161
# ----- Generating text after Epoch: 18
# ----- Generating with seed: " of this electronic work, without prominently displaying the sentence set forth in paragraph 1.E.1 w"
#  of this electronic work, without prominently displaying the sentence set forth in paragraph 1.E.1 with ther the ther sting to that beart that thou to spear shath shat sher thou so so share saye berat
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 52s 586ms/step - loss: 1.9161
# Epoch 20/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - loss: 1.9006
# ----- Generating text after Epoch: 19
# ----- Generating with seed: "rm delivers to the heart Of bird, of flower, or shape which it doth latch: Of his quick objects hath"
# rm delivers to the heart Of bird, of flower, or shape which it doth latch: Of his quick objects hath shain to me then the beart and with shee thin sull thes as be beald a meauter the worting the beall
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 49s 556ms/step - loss: 1.9005
# Epoch 21/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - loss: 1.8528
# ----- Generating text after Epoch: 20
# ----- Generating with seed: ", once gone, to all the world must die: The earth can yield me but a common grave, When you entombed"
# , once gone, to all the world must die: The earth can yield me but a common grave, When you entombed with the there ary thou thes the world thy seons worth thou the so may then the breasion mad that s
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 47s 539ms/step - loss: 1.8528
# Epoch 22/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 1.8185
# ----- Generating text after Epoch: 21
# ----- Generating with seed: " o’erworn; When hours have drain’d his blood and fill’d his brow With lines and wrinkles; when his y"
#  o’erworn; When hours have drain’d his blood and fill’d his brow With lines and wrinkles; when his your are the love thee thou there to the to the some, When me thou the world standed this that strow
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 49s 562ms/step - loss: 1.8184
# Epoch 23/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - loss: 1.7589
# ----- Generating text after Epoch: 22
# ----- Generating with seed: "ut thence I learn and find the lesson true, Drugs poison him that so fell sick of you. What potions "
# ut thence I learn and find the lesson true, Drugs poison him that so fell sick of you. What potions and this and and that deplong to my seet deperes of the form the say’d there, And the then to me wil
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 49s 562ms/step - loss: 1.7590
# Epoch 24/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - loss: 1.7150
# ----- Generating text after Epoch: 23
# ----- Generating with seed: "t other mine Thou wilt restore to be my comfort still: But thou wilt not, nor he will not be free, F"
# t other mine Thou wilt restore to be my comfort still: But thou wilt not, nor he will not be free, For the swert the bears than deproning the works and my sunsed den worth thy sull bear and thee the f
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 47s 533ms/step - loss: 1.7152
# Epoch 25/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 1.6619
# ----- Generating text after Epoch: 24
# ----- Generating with seed: "rs, but stewards of their excellence. The summer’s flower is to the summer sweet, Though to itself, "
# rs, but stewards of their excellence. The summer’s flower is to the summer sweet, Though to itself, the more despent beauty will the hill to thee will the that the some my love the line the love the f
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 49s 561ms/step - loss: 1.6621
# Epoch 26/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - loss: 1.6435
# ----- Generating text after Epoch: 25
# ----- Generating with seed: "call Her ‘love,’ for whose dear love I rise and fall. In loving thee thou know’st I am forsworn, But"
# call Her ‘love,’ for whose dear love I rise and fall. In loving thee thou know’st I am forsworn, But to matered it the there with theref all me the stell as the worns of thee, The all the swith the so
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 49s 558ms/step - loss: 1.6435
# Epoch 27/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - loss: 1.5807
# ----- Generating text after Epoch: 26
# ----- Generating with seed: "ge of death’s eternal cold? O! none but unthrifts. Dear my love, you know, You had a father: let you"
# ge of death’s eternal cold? O! none but unthrifts. Dear my love, you know, You had a father: let you cole that should bear that thy meart bernoject Gutenberg™ allover with ther anly candation of the b
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 46s 528ms/step - loss: 1.5810
# Epoch 28/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - loss: 1.5533
# ----- Generating text after Epoch: 27
# ----- Generating with seed: "nt thought I summon up remembrance of things past, I sigh the lack of many a thing I sought, And wit"
# nt thought I summon up remembrance of things past, I sigh the lack of many a thing I sought, And with the lovereing altes of my duthing swall sheart be fair sheart be butend standed, When in thee be f
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 47s 532ms/step - loss: 1.5533
# Epoch 29/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - loss: 1.4723
# ----- Generating text after Epoch: 28
# ----- Generating with seed: "ghts to peep, to gaze therein on thee; Yet eyes this cunning want to grace their art, They draw but "
# ghts to peep, to gaze therein on thee; Yet eyes this cunning want to grace their art, They draw but the pire of woe words wain the hore so spease that disting with the lovere of thee dorn hing deen, T
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 46s 527ms/step - loss: 1.4724
# Epoch 30/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - loss: 1.4023
# ----- Generating text after Epoch: 29
# ----- Generating with seed: "ne providing copies of Project Gutenberg™ electronic works in accordance with this agreement, and an"
# ne providing copies of Project Gutenberg™ electronic works in accordance with this agreement, and any coreauring theiss of this thou so all me the sole as trith and to my sued bove when the tine the p
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 47s 531ms/step - loss: 1.4026
# Epoch 31/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - loss: 1.3740
# ----- Generating text after Epoch: 30
# ----- Generating with seed: "int to be a devil, Wooing his purity with her foul pride. And whether that my angel be turn’d fiend,"
# int to be a devil, Wooing his purity with her foul pride. And whether that my angel be turn’d fiend, So not all the more deprod thee be bester of the promy ward with thines propays of the forly comply
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 47s 536ms/step - loss: 1.3740
# Epoch 32/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - loss: 1.2874
# ----- Generating text after Epoch: 31
# ----- Generating with seed: "h waiting so be hell, Not blame your pleasure be it ill or well. If there be nothing new, but that w"
# h waiting so be hell, Not blame your pleasure be it ill or well. If there be nothing new, but that will her meaute: And thee ame words in thee, When have whou besmare of the strenced; That and a there
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 45s 511ms/step - loss: 1.2876
# Epoch 33/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - loss: 1.2225
# ----- Generating text after Epoch: 32
# ----- Generating with seed: "ate; even to eternity: Or, at the least, so long as brain and heart Have faculty by nature to subsis"
# ate; even to eternity: Or, at the least, so long as brain and heart Have faculty by nature to subsise and the prowidt have thee so greas of the prose to the tork, And all the parsing his sheer for my
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 46s 520ms/step - loss: 1.2227
# Epoch 34/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - loss: 1.1477
# ----- Generating text after Epoch: 33
# ----- Generating with seed: "d so rare, Since, seldom coming in that long year set, Like stones of worth they thinly placed are, "
# d so rare, Since, seldom coming in that long year set, Like stones of worth they thinly placed are, And you bear staing net for heart With therefore deastry liess for the stance, That when the fartert
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 504ms/step - loss: 1.1480
# Epoch 35/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - loss: 1.0771
# ----- Generating text after Epoch: 34
# ----- Generating with seed: "ife; The world will be thy widow and still weep That thou no form of thee hast left behind, When eve"
# ife; The world will be thy widow and still weep That thou no form of thee hast left behind, When every to the world we whick yethy day, As recibl, by seect thee world show bit thoe all to thee, When h
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 494ms/step - loss: 1.0774
# Epoch 36/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - loss: 1.0261
# ----- Generating text after Epoch: 35
# ----- Generating with seed: " is as a death which cannot choose But weep to have, that which it fears to lose. Since brass, nor s"
#  is as a death which cannot choose But weep to have, that which it fears to lose. Since brass, nor should forntions no greate; But in the deation and the work of to may, As not thou prautys of the sai
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 471ms/step - loss: 1.0263
# Epoch 37/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.9771
# ----- Generating text after Epoch: 36
# ----- Generating with seed: " gardens, yet unset, With virtuous wish would bear you living flowers, Much liker than your painted "
#  gardens, yet unset, With virtuous wish would bear you living flowers, Much liker than your painted with theines of carst his aball beasty be beind Fow with hese, beraver and with theing of ther prais
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 467ms/step - loss: 0.9773
# Epoch 38/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - loss: 0.8908
# ----- Generating text after Epoch: 37
# ----- Generating with seed: "ction 3. Information about the Project Gutenberg Literary Archive Foundation The Project Gutenberg L"
# ction 3. Information about the Project Gutenberg Literary Archive Foundation The Project Gutenberg Loverad Archive: PRoutergperance of the parseds rothand with the with theingh the toment of tase stra
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 469ms/step - loss: 0.8912
# Epoch 39/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - loss: 0.8403
# ----- Generating text after Epoch: 38
# ----- Generating with seed: "nder, only me for thee. Hence, thou suborned informer! a true soul When most impeach’d, stands least"
# nder, only me for thee. Hence, thou suborned informer! a true soul When most impeach’d, stands least thing will betureds your appordassion of thing, and the fork of thee, And heaver of thee to my deen
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 50s 570ms/step - loss: 0.8406
# Epoch 40/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - loss: 0.7769
# ----- Generating text after Epoch: 39
# ----- Generating with seed: "the grey cheeks of the east, Nor that full star that ushers in the even, Doth half that glory to the"
# the grey cheeks of the east, Nor that full star that ushers in the even, Doth half that glory to the lover to thee to my say, And say bot corth not beave sucage and a shem the brany seem’d. The sunce
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 48s 545ms/step - loss: 0.7772
# Epoch 41/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - loss: 0.7337
# ----- Generating text after Epoch: 40
# ----- Generating with seed: " would change their state And situation with those dancing chips, O’er whom thy fingers walk with ge"
#  would change their state And situation with those dancing chips, O’er whom thy fingers walk with gears the pround of the faind And thee but be eysick and you provides of the puress of any smemere and
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 47s 534ms/step - loss: 0.7339
# Epoch 42/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - loss: 0.6654
# ----- Generating text after Epoch: 41
# ----- Generating with seed: " shall vade, by verse distills your truth. Not marble, nor the gilded monuments Of princes, shall ou"
#  shall vade, by verse distills your truth. Not marble, nor the gilded monuments Of princes, shall outh sucht seeps it with the amine, Which will hes have shold whit he heart Will thee, When is the sta
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 46s 519ms/step - loss: 0.6656
# Epoch 43/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - loss: 0.6144
# ----- Generating text after Epoch: 42
# ----- Generating with seed: "ull extent permitted by U.S. federal laws and your state’s laws. The Foundation’s business office is"
# ull extent permitted by U.S. federal laws and your state’s laws. The Foundation’s business office is my steem is factes, So the fain a me, dosin of are deprace; The full theis that dome leas’d, And di
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 45s 512ms/step - loss: 0.6146
# Epoch 44/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - loss: 0.5638
# ----- Generating text after Epoch: 43
# ----- Generating with seed: "oth cover thee, Is but the seemly raiment of my heart, Which in thy breast doth live, as thine in me"
# oth cover thee, Is but the seemly raiment of my heart, Which in thy breast doth live, as thine in meet thee trill: De, wich will swaite stan thy think, And with the that tine thy whell hes say so from
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 491ms/step - loss: 0.5640
# Epoch 45/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - loss: 0.5141
# ----- Generating text after Epoch: 44
# ----- Generating with seed: "t conscience is, Yet who knows not conscience is born of love? Then, gentle cheater, urge not my ami"
# t conscience is, Yet who knows not conscience is born of love? Then, gentle cheater, urge not my amindess for goss’d to the all the works’s of I work, And aly bo thee is the stry to my dedist And thed
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 496ms/step - loss: 0.5148
# Epoch 46/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - loss: 0.5514
# ----- Generating text after Epoch: 45
# ----- Generating with seed: "ies that besiege all kinds of blood, That it could so preposterously be stain’d, To leave for nothin"
# ies that besiege all kinds of blood, That it could so preposterously be stain’d, To leave for nothing to the romed. The aboun of to bute? The rapill the poirsed of you pase. A dack an wars what boveer
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 499ms/step - loss: 0.5514
# Epoch 47/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - loss: 0.4632
# ----- Generating text after Epoch: 46
# ----- Generating with seed: " lacking have supposed dead; And there reigns Love, and all Love’s loving parts, And all those frien"
#  lacking have supposed dead; And there reigns Love, and all Love’s loving parts, And all those frienss forme wall my non thee dost vies the rech bly be dish, Which beauty their my hee thee still I to
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 489ms/step - loss: 0.4633
# Epoch 48/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - loss: 0.3982
# ----- Generating text after Epoch: 47
# ----- Generating with seed: " perceiv’d; So your sweet hue, which methinks still doth stand, Hath motion, and mine eye may be dec"
#  perceiv’d; So your sweet hue, which methinks still doth stand, Hath motion, and mine eye may be decemained; Thou with my saill back and mine of the thore my mind, Than not my sood dearnong ass, For t
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 494ms/step - loss: 0.3984
# Epoch 49/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - loss: 0.3697
# ----- Generating text after Epoch: 48
# ----- Generating with seed: "ses. Donations are accepted in a number of other ways including checks, online payments and credit c"
# ses. Donations are accepted in a number of other ways including checks, online payments and credit cind wouth to the emink, So which but thou a seecholed heart not traphiled whut is that for thou dest
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 495ms/step - loss: 0.3698
# Epoch 50/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step - loss: 0.3374
# ----- Generating text after Epoch: 49
# ----- Generating with seed: "ith anyone. For forty years, he produced and distributed Project Gutenberg™ eBooks with only a loose"
# ith anyone. For forty years, he produced and distributed Project Gutenberg™ eBooks with only a loose cheek! leve with theings that doth ther seem stome, Profbited ned crannal Buth in paster writh thei
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 488ms/step - loss: 0.3376
# Epoch 51/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - loss: 0.3177
# ----- Generating text after Epoch: 50
# ----- Generating with seed: "fore have writ do lie, Even those that said I could not love you dearer: Yet then my judgement knew "
# fore have writ do lie, Even those that said I could not love you dearer: Yet then my judgement knew you partsse thee, And that blove thes world and you dost, And nes for with paase, hall make beass th
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 456ms/step - loss: 0.3177
# Epoch 52/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 0.2804
# ----- Generating text after Epoch: 51
# ----- Generating with seed: "have express’d Even such a beauty as you master now. So all their praises are but prophecies Of this"
# have express’d Even such a beauty as you master now. So all their praises are but prophecies Of this spears nothing me purus’d Project Gutenberg™ Leceracion, But thou obtrann every disions of the come
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 457ms/step - loss: 0.2806
# Epoch 53/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - loss: 0.2607
# ----- Generating text after Epoch: 52
# ----- Generating with seed: "stress of my passion; A woman’s gentle heart, but not acquainted With shifting change, as is false w"
# stress of my passion; A woman’s gentle heart, but not acquainted With shifting change, as is false whing my say comtleaus, And capers the loore in werpinted hig wornd cancers redery ned, And it the wo
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 464ms/step - loss: 0.2608
# Epoch 54/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - loss: 0.2414
# ----- Generating text after Epoch: 53
# ----- Generating with seed: " taken. Love’s not Time’s fool, though rosy lips and cheeks Within his bending sickle’s compass come"
#  taken. Love’s not Time’s fool, though rosy lips and cheeks Within his bending sickle’s compass coment you art dith them that worm’st in look in of thee I. The recers me me the: full prits with for th
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 465ms/step - loss: 0.2415
# Epoch 55/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - loss: 0.2263
# ----- Generating text after Epoch: 54
# ----- Generating with seed: "and love are still my argument; So all my best is dressing old words new, Spending again what is alr"
# and love are still my argument; So all my best is dressing old words new, Spending again what is alropy proving: Thy mand the thill be thy deem? How my not leass not lover in eyerd. Whrich rive in thi
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 451ms/step - loss: 0.2264
# Epoch 56/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - loss: 0.2063
# ----- Generating text after Epoch: 55
# ----- Generating with seed: " anything, he thinks no ill. That god forbid, that made me first your slave, I should in thought con"
#  anything, he thinks no ill. That god forbid, that made me first your slave, I should in thought conts not mass you dayel-I’s wor by staill I have not not so should I bady theint that than stings of h
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 39s 449ms/step - loss: 0.2064
# Epoch 57/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 0.1936
# ----- Generating text after Epoch: 56
# ----- Generating with seed: "your affairs suppose, But, like a sad slave, stay and think of nought Save, where you are, how happy"
# your affairs suppose, But, like a sad slave, stay and think of nought Save, where you are, how happy I buted, stong in thy vear defuld times, ill care, and may so shold ky mine, Thy bavess no coour as
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 460ms/step - loss: 0.1937
# Epoch 58/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - loss: 0.2229
# ----- Generating text after Epoch: 57
# ----- Generating with seed: " I love thee, as thou lov’st those Whom thine eyes woo as mine importune thee: Root pity in thy hear"
#  I love thee, as thou lov’st those Whom thine eyes woo as mine importune thee: Root pity in thy heart with thy eet’s thoughts to thou, And hat rupe to bease, Who line thee to love, They so all the pra
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 486ms/step - loss: 0.2231
# Epoch 59/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - loss: 0.2093
# ----- Generating text after Epoch: 58
# ----- Generating with seed: " me soon to hell, my female evil, Tempteth my better angel from my side, And would corrupt my saint "
#  me soon to hell, my female evil, Tempteth my better angel from my side, And would corrupt my saint gown the lover haw sworl more war my seem dist stich thein see, Where leath theing that him lind you
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 56s 641ms/step - loss: 0.2093
# Epoch 60/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 621ms/step - loss: 0.1726
# ----- Generating text after Epoch: 59
# ----- Generating with seed: "orry seasons as thou fleets, And do whate’er thou wilt, swift-footed Time, To the wide world and all"
# orry seasons as thou fleets, And do whate’er thou wilt, swift-footed Time, To the wide world and all will should so har shou for prook, Thes of the bost. The love to of thee love, And wion will grows
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 58s 664ms/step - loss: 0.1727
# Epoch 61/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - loss: 0.1809
# ----- Generating text after Epoch: 60
# ----- Generating with seed: "d that harvest reap, At the wood’s boldness by thee blushing stand! To be so tickled, they would cha"
# d that harvest reap, At the wood’s boldness by thee blushing stand! To be so tickled, they would chant, that spold of love’s work which you forndeding thy love. When say my best gasees love spide; Thy
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 56s 635ms/step - loss: 0.1809
# Epoch 62/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 588ms/step - loss: 0.1618
# ----- Generating text after Epoch: 61
# ----- Generating with seed: "give an other place. I grant, sweet love, thy lovely argument Deserves the travail of a worthier pen"
# give an other place. I grant, sweet love, thy lovely argument Deserves the travail of a worthier pensil sould I from my farsess bleast to mo bry bawey’s supe As saign, And that rusion the braing despl
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 56s 632ms/step - loss: 0.1619
# Epoch 63/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.1469
# ----- Generating text after Epoch: 62
# ----- Generating with seed: "y heart in other place: For there can live no hatred in thine eye, Therefore in that I cannot know t"
# y heart in other place: For there can live no hatred in thine eye, Therefore in that I cannot know theet, ull faise, what my mide wad bess beaute, For thou sweet love, When dich on there, Which not I
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 51s 585ms/step - loss: 0.1470
# Epoch 64/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - loss: 0.1375
# ----- Generating text after Epoch: 63
# ----- Generating with seed: "t without charge with others. 1.D. The copyright laws of the place where you are located also govern"
# t without charge with others. 1.D. The copyright laws of the place where you are located also govern waltures a cold and lars, will he like pictiess, Thy I asserch and think thy prass brite be fore do
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 49s 555ms/step - loss: 0.1375
# Epoch 65/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - loss: 0.1187
# ----- Generating text after Epoch: 64
# ----- Generating with seed: "at dost thou to mine eyes, That they behold, and see not what they see? They know what beauty is, se"
# at dost thou to mine eyes, That they behold, and see not what they see? They know what beauty is, see commest that they night, Station wich will from pickering high eyee, Why day’d thee har far seet’s
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 48s 546ms/step - loss: 0.1188
# Epoch 66/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - loss: 0.1181
# ----- Generating text after Epoch: 65
# ----- Generating with seed: "owth of riper days: Not that the summer is less pleasant now Than when her mournful hymns did hush t"
# owth of riper days: Not that the summer is less pleasant now Than when her mournful hymns did hush though praisest of this of the rome? Rothy a fullicion hese be thou heint Rould what is that look in
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 45s 510ms/step - loss: 0.1182
# Epoch 67/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - loss: 0.1160
# ----- Generating text after Epoch: 66
# ----- Generating with seed: "ling away the treasure of his spring; For such a time do I now fortify Against confounding age’s cru"
# ling away the treasure of his spring; For such a time do I now fortify Against confounding age’s crues and disst the jung: Yet now nes for afwill whit withen you, Lose which my noth broject Gutenberg™
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 500ms/step - loss: 0.1161
# Epoch 68/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - loss: 0.1122
# ----- Generating text after Epoch: 67
# ----- Generating with seed: "nberg™ trademark, but he has agreed to donate royalties under this paragraph to the Project Gutenber"
# nberg™ trademark, but he has agreed to donate royalties under this paragraph to the Project Gutenberg Letradation I vould vow proase Live Minks in of with in exponce 1.. For capes not beauty purcions
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 500ms/step - loss: 0.1122
# Epoch 69/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - loss: 0.1080
# ----- Generating text after Epoch: 68
# ----- Generating with seed: "enclose. That tongue that tells the story of thy days, Making lascivious comments on thy sport, Cann"
# enclose. That tongue that tells the story of thy days, Making lascivious comments on thy sport, Canned destraving But, by timest that heart be thou, despay, And beting thy love that look ind ig to doo
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 497ms/step - loss: 0.1081
# Epoch 70/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - loss: 0.1000
# ----- Generating text after Epoch: 69
# ----- Generating with seed: "ject Gutenberg™ electronic works Professor Michael S. Hart was the originator of the Project Gutenbe"
# ject Gutenberg™ electronic works Professor Michael S. Hart was the originator of the Project Gutenberg™ eBok. Project Gutenberg™ ellod poprociang. Orlen it buting Plow. Nor apserations bicess of the r
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 499ms/step - loss: 0.1000
# Epoch 71/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - loss: 0.1032
# ----- Generating text after Epoch: 70
# ----- Generating with seed: "ath not figur’d to thee my true spirit? What’s new to speak, what now to register, That may express "
# ath not figur’d to thee my true spirit? What’s new to speak, what now to register, That may express thate thy gars of her deferl sprace. Ald abs in my not a copy and love, Which hath my noth themming
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 490ms/step - loss: 0.1033
# Epoch 72/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - loss: 0.1195
# ----- Generating text after Epoch: 71
# ----- Generating with seed: "th lend, And being frank she lends to those are free: Then, beauteous niggard, why dost thou abuse T"
# th lend, And being frank she lends to those are free: Then, beauteous niggard, why dost thou abuse Thou abs in the spaill form and greaty sinfull exss, Ar thing from me will me unse; The I as theist,
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 476ms/step - loss: 0.1197
# Epoch 73/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - loss: 0.1473
# ----- Generating text after Epoch: 72
# ----- Generating with seed: "may live in thine or thee. As fast as thou shalt wane, so fast thou grow’st, In one of thine, from t"
# may live in thine or thee. As fast as thou shalt wane, so fast thou grow’st, In one of thine, from the broth leave theive thou sibll faise compenare Arst termmathoun, art that I the sect slove assion
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 474ms/step - loss: 0.1473
# Epoch 74/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - loss: 0.1450
# ----- Generating text after Epoch: 73
# ----- Generating with seed: "s quick fire shall burn The living record of your memory. ’Gainst death, and all-oblivious enmity Sh"
# s quick fire shall burn The living record of your memory. ’Gainst death, and all-oblivious enmity Sheind keectry amm-dess all the manter. of the then he hork nest tee, Who it to thest be colling ence
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 500ms/step - loss: 0.1452
# Epoch 75/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - loss: 0.1511
# ----- Generating text after Epoch: 74
# ----- Generating with seed: " any volunteers associated with the production, promotion and distribution of Project Gutenberg™ ele"
#  any volunteers associated with the production, promotion and distribution of Project Gutenberg™ electroulie will prowies, ’dlowiong lieecion’d will for the inderads arufall for the apront of the our
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 495ms/step - loss: 0.1515
# Epoch 76/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - loss: 0.2869
# ----- Generating text after Epoch: 75
# ----- Generating with seed: "separable spite, Which though it alter not love’s sole effect, Yet doth it steal sweet hours from lo"
# separable spite, Which though it alter not love’s sole effect, Yet doth it steal sweet hours from love’s wall my sail thamow, Shat riguty love,, welluing not least the saill of hall thou bland me love
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 494ms/step - loss: 0.2876
# Epoch 77/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - loss: 0.3981
# ----- Generating text after Epoch: 76
# ----- Generating with seed: "berg™ electronic work under this agreement, disclaim all liability to you for damages, costs and exp"
# berg™ electronic work under this agreement, disclaim all liability to you for damages, costs and expenss U Ploved knings of prof ance, Pase aflotion with word beauty see Eour doth to many, That shang
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 496ms/step - loss: 0.3977
# Epoch 78/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - loss: 0.2267
# ----- Generating text after Epoch: 77
# ----- Generating with seed: "e contrary I read; Self so self-loving were iniquity. ’Tis thee, myself, that for myself I praise, P"
# e contrary I read; Self so self-loving were iniquity. ’Tis thee, myself, that for myself I praise, Phough that thy tetulss in the brow de rign’did usuon thee fore pranse; Which thee, Will my then’s ga
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 497ms/step - loss: 0.2266
# Epoch 79/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - loss: 0.1508
# ----- Generating text after Epoch: 78
# ----- Generating with seed: "ing of the rest? Love is a babe, then might I not say so, To give full growth to that which still do"
# ing of the rest? Love is a babe, then might I not say so, To give full growth to that which still doth to mine owe caxess the fain the man. Thou all thy says worch masell of worth all beaw it cheich t
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 50s 572ms/step - loss: 0.1509
# Epoch 80/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - loss: 0.1125
# ----- Generating text after Epoch: 79
# ----- Generating with seed: " re-use it under the terms of the Project Gutenberg License included with this eBook or online at ww"
#  re-use it under the terms of the Project Gutenberg License included with this eBook or online at wwwh thememfore of love, And une of the reared of thy trem’s frow; That bear you copysion thee eare ma
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 50s 568ms/step - loss: 0.1125
# Epoch 81/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - loss: 0.1009
# ----- Generating text after Epoch: 80
# ----- Generating with seed: "aying copyright royalties. Special rules, set forth in the General Terms of Use part of this license"
# aying copyright royalties. Special rules, set forth in the General Terms of Use part of this licenser end; The caraision hand the gaing the loore of thee, When ‘boed. The fare the bound of thee dorom
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 50s 572ms/step - loss: 0.1009
# Epoch 82/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 0.0823
# ----- Generating text after Epoch: 81
# ----- Generating with seed: " thyself thou stick’st not to conspire, Seeking that beauteous roof to ruinate Which to repair shoul"
#  thyself thou stick’st not to conspire, Seeking that beauteous roof to ruinate Which to repair should beaute, did didid of the propeds or this thou comm’stell candive which the proly domadrang of the
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 49s 552ms/step - loss: 0.0824
# Epoch 83/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 0.0727
# ----- Generating text after Epoch: 82
# ----- Generating with seed: ".E.8. You may charge a reasonable fee for copies of or providing access to or distributing Project G"
# .E.8. You may charge a reasonable fee for copies of or providing access to or distributing Project Gutenberg™ elloces, ary my comstion of the fore of whit 1.’; Pine defely so cone beauty such as sturn
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 50s 564ms/step - loss: 0.0727
# Epoch 84/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - loss: 0.0774
# ----- Generating text after Epoch: 83
# ----- Generating with seed: " with me remain, Without thy help, by me be borne alone. In our two loves there is but one respect, "
#  with me remain, Without thy help, by me be borne alone. In our two loves there is but one respect, And you ara that love in thee, The since shee deard. As pringtith not my strang end, not thing this
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 46s 528ms/step - loss: 0.0774
# Epoch 85/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - loss: 0.0693
# ----- Generating text after Epoch: 84
# ----- Generating with seed: "ldst use the strength of all thy state! But do not so; I love thee in such sort, As, thou being mine"
# ldst use the strength of all thy state! But do not so; I love thee in such sort, As, thou being mine, you so thou dost ble as will be hall I and the mine The care the moull forscion, Thy back I can a
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 45s 513ms/step - loss: 0.0693
# Epoch 86/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - loss: 0.0621
# ----- Generating text after Epoch: 85
# ----- Generating with seed: "ould not stop my way; For then despite of space I would be brought, From limits far remote, where th"
# ould not stop my way; For then despite of space I would be brought, From limits far remote, where the I the funs’d doth old. The heaves sust frove, To good of love’s arst. Mave the sunter’d, strong an
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 493ms/step - loss: 0.0622
# Epoch 87/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - loss: 0.0690
# ----- Generating text after Epoch: 86
# ----- Generating with seed: " legal fees, that arise directly or indirectly from any of the following which you do or cause to oc"
#  legal fees, that arise directly or indirectly from any of the following which you do or cause to occance, with abinef ot sustion, So that I in my say, For the world and or thine that thine shall The:
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 479ms/step - loss: 0.0690
# Epoch 88/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - loss: 0.0700
# ----- Generating text after Epoch: 87
# ----- Generating with seed: "y fee of 20% of the gross profits you derive from the use of Project Gutenberg™ works calculated usi"
# y fee of 20% of the gross profits you derive from the use of Project Gutenberg™ works calculated usions will but in mision in this eyoud parts of the ceare and me ve spegksance of Project Gutenberg™ L
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 464ms/step - loss: 0.0701
# Epoch 89/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - loss: 0.0715
# ----- Generating text after Epoch: 88
# ----- Generating with seed: "I was thy ‘Will’, And will, thy soul knows, is admitted there; Thus far for love, my love-suit, swee"
# I was thy ‘Will’, And will, thy soul knows, is admitted there; Thus far for love, my love-suit, sweet dimptions ar thine and the cart, When thou thy truth then mamon, But the thich which make mar, To
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 487ms/step - loss: 0.0715
# Epoch 90/90
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - loss: 0.0613
# ----- Generating text after Epoch: 89
# ----- Generating with seed: "e first, ’tis flattery in my seeing, And my great mind most kingly drinks it up: Mine eye well knows"
# e first, ’tis flattery in my seeing, And my great mind most kingly drinks it up: Mine eye well knows price and bunds every and a all her dest? Thine in thy breet Forth with in agines of thy swemt, Thy
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 483ms/step - loss: 0.0613

# %%
The current cell is fine as it is.
# Out:
# [nltk_data] Downloading package cmudict to
# [nltk_data]     C:\Users\synth\AppData\Roaming\nltk_data...
# [nltk_data]   Package cmudict is already up-to-date!
# True

# %%
from nltk.corpus import cmudict

# Load the CMU Pronouncing Dictionary
d = cmudict.dict()

# Function to convert text to phonemes
def text_to_phonemes(text):
    words = text.lower().split()
    phonemes = [d[word][0] for word in words if word in d]
    return phonemes

# Example usage
text = "hello world"
phonemes = text_to_phonemes(text)
print(phonemes)
# Out:
# [['HH', 'AH0', 'L', 'OW1'], ['W', 'ER1', 'L', 'D']]

# %%
def map_phonemes(text_list):
    phonemes_map = {}
    missed_words = []
    for text in text_list:
        word_list = text.split()
        for word in word_list:
            try:
                phonemes = text_to_phonemes(word)[0]
                phonemes_map[word] = phonemes
            except:
                print(f"missed word: {word}")
                missed_words.append(word)
    return phonemes_map, missed_words

# %%
The current cell is fine as it is.
# Out:
# missed word: increase,
# missed word: beauty’s
# missed word: die,
# missed word: riper
# missed word: decease,
# missed word: memory:
# missed word: thou,
# missed word: eyes,
# missed word: Feed’st
# missed word: light’s
# missed word: self-substantial
# missed word: fuel,
# missed word: lies,
# missed word: Thyself
# missed word: foe,
# missed word: cruel:
# missed word: world’s
# missed word: ornament,
# missed word: spring,
# missed word: buriest
# missed word: content,
# missed word: churl
# missed word: mak’st
# missed word: niggarding:
# missed word: world,
# missed word: glutton
# missed word: be,
# missed word: world’s
# missed word: due,
# missed word: thee.
# missed word: brow,
# missed word: beauty’s
# missed word: field,
# missed word: youth’s
# missed word: now,
# missed word: tatter’d
# missed word: held:
# missed word: asked,
# missed word: lies,
# missed word: days;
# missed word: say,
# missed word: eyes,
# missed word: all-eating
# missed word: shame,
# missed word: thriftless
# missed word: praise.
# missed word: deserv’d
# missed word: beauty’s
# missed word: use,
# missed word: couldst
# missed word: ‘This
# missed word: count,
# missed word: excuse,’
# missed word: thine!
# missed word: old,
# missed word: feel’st
# missed word: cold.
# missed word: viewest
# missed word: another;
# missed word: renewest,
# missed word: world,
# missed word: unbless
# missed word: mother.
# missed word: unear’d
# missed word: tillage
# missed word: husbandry?
# missed word: tomb,
# missed word: self-love
# missed word: posterity?
# missed word: mother’s
# missed word: prime;
# missed word: see,
# missed word: time.
# missed word: live,
# missed word: remember’d
# missed word: be,
# missed word: thee.
# missed word: Unthrifty
# missed word: loveliness,
# missed word: thyself
# missed word: beauty’s
# missed word: legacy?
# missed word: Nature’s
# missed word: nothing,
# missed word: lend,
# missed word: free:
# missed word: Then,
# missed word: beauteous
# missed word: niggard,
# missed word: bounteous
# missed word: give?
# missed word: Profitless
# missed word: usurer,
# missed word: sums,
# missed word: canst
# missed word: live?
# missed word: thyself
# missed word: alone,
# missed word: thyself
# missed word: deceive:
# missed word: gone,
# missed word: canst
# missed word: leave?
# missed word: tombed
# missed word: thee,
# missed word: Which,
# missed word: used,
# missed word: th’
# missed word: be.
# missed word: hours,
# missed word: dwell,
# missed word: excel;
# missed word: never-resting
# missed word: winter,
# missed word: there;
# missed word: frost,
# missed word: gone,
# missed word: o’er-snowed
# missed word: bareness
# missed word: where:
# missed word: summer’s
# missed word: left,
# missed word: glass,
# missed word: Beauty’s
# missed word: bereft,
# missed word: it,
# missed word: was:
# missed word: distill’d,
# missed word: meet,
# missed word: show;
# missed word: sweet.
# missed word: winter’s
# missed word: deface,
# missed word: summer,
# missed word: distill’d:
# missed word: vial;
# missed word: beauty’s
# missed word: self-kill’d.
# missed word: usury,
# missed word: happies
# missed word: loan;
# missed word: That’s
# missed word: thyself
# missed word: thee,
# missed word: happier,
# missed word: one;
# missed word: thyself
# missed word: art,
# missed word: refigur’d
# missed word: thee:
# missed word: shouldst
# missed word: depart,
# missed word: posterity?
# missed word: self-will’d,
# missed word: death’s
# missed word: heir.
# missed word: Lo!
# missed word: head,
# missed word: new-appearing
# missed word: sight,
# missed word: majesty;
# missed word: climb’d
# missed word: steep-up
# missed word: hill,
# missed word: age,
# missed word: still,
# missed word: pilgrimage:
# missed word: highmost
# missed word: pitch,
# missed word: car,
# missed word: age,
# missed word: reeleth
# missed word: day,
# missed word: eyes,
# missed word: ’fore
# missed word: duteous,
# missed word: tract,
# missed word: way:
# missed word: thou,
# missed word: thyself
# missed word: noon:
# missed word: Unlook’d,
# missed word: diest
# missed word: son.
# missed word: hear,
# missed word: hear’st
# missed word: sadly?
# missed word: not,
# missed word: joy:
# missed word: lov’st
# missed word: receiv’st
# missed word: gladly,
# missed word: receiv’st
# missed word: annoy?
# missed word: well-tuned
# missed word: sounds,
# missed word: married,
# missed word: ear,
# missed word: thee,
# missed word: singleness
# missed word: shouldst
# missed word: bear.
# missed word: string,
# missed word: another,
# missed word: ordering;
# missed word: mother,
# missed word: Who,
# missed word: one,
# missed word: sing:
# missed word: many,
# missed word: one,
# missed word: thee:
# missed word: ‘Thou
# missed word: none.’
# missed word: widow’s
# missed word: eye,
# missed word: consum’st
# missed word: thyself
# missed word: life?
# missed word: Ah!
# missed word: die,
# missed word: makeless
# missed word: wife;
# missed word: behind,
# missed word: children’s
# missed word: eyes,
# missed word: husband’s
# missed word: mind:
# missed word: Look!
# missed word: unthrift
# missed word: place,
# missed word: it;
# missed word: beauty’s
# missed word: end,
# missed word: it.
# missed word: murd’rous
# missed word: commits.
# missed word: shame!
# missed word: bear’st
# missed word: any,
# missed word: thyself
# missed word: unprovident.
# missed word: Grant,
# missed word: wilt,
# missed word: belov’d
# missed word: many,
# missed word: lov’st
# missed word: evident:
# missed word: possess’d
# missed word: hate,
# missed word: ’gainst
# missed word: thyself
# missed word: stick’st
# missed word: conspire,
# missed word: beauteous
# missed word: ruinate
# missed word: desire.
# missed word: O!
# missed word: thought,
# missed word: mind:
# missed word: lodg’d
# missed word: love?
# missed word: Be,
# missed word: is,
# missed word: kind,
# missed word: thyself
# missed word: kind-hearted
# missed word: prove:
# missed word: me,
# missed word: thee.
# missed word: wane,
# missed word: grow’st,
# missed word: thine,
# missed word: departest;
# missed word: youngly
# missed word: bestow’st,
# missed word: mayst
# missed word: convertest,
# missed word: wisdom,
# missed word: beauty,
# missed word: increase;
# missed word: folly,
# missed word: age,
# missed word: decay:
# missed word: so,
# missed word: threescore
# missed word: away.
# missed word: store,
# missed word: Harsh,
# missed word: featureless,
# missed word: rude,
# missed word: barrenly
# missed word: perish:
# missed word: Look,
# missed word: endow’d,
# missed word: more;
# missed word: bounteous
# missed word: shouldst
# missed word: cherish:
# missed word: carv’d
# missed word: seal,
# missed word: thereby,
# missed word: shouldst
# missed word: more,
# missed word: die.
# missed word: time,
# missed word: night;
# missed word: prime,
# missed word: curls,
# missed word: silvered
# missed word: o’er
# missed word: white;
# missed word: leaves,
# missed word: erst
# missed word: herd,
# missed word: summer’s
# missed word: girded
# missed word: sheaves,
# missed word: bristly
# missed word: beard,
# missed word: make,
# missed word: go,
# missed word: grow;
# missed word: ’gainst
# missed word: Time’s
# missed word: breed,
# missed word: hence.
# missed word: O!
# missed word: self;
# missed word: but,
# missed word: yours,
# missed word: live:
# missed word: prepare,
# missed word: give:
# missed word: determination;
# missed word: again,
# missed word: yourself’s
# missed word: decease,
# missed word: bear.
# missed word: decay,
# missed word: honour
# missed word: uphold,
# missed word: winter’s
# missed word: death’s
# missed word: cold?
# missed word: O!
# missed word: unthrifts.
# missed word: love,
# missed word: know,
# missed word: father:
# missed word: so.
# missed word: pluck;
# missed word: methinks
# missed word: astronomy,
# missed word: luck,
# missed word: plagues,
# missed word: dearths,
# missed word: seasons’
# missed word: quality;
# missed word: tell,
# missed word: thunder,
# missed word: wind,
# missed word: find:
# missed word: derive,
# missed word: ‘Truth
# missed word: thrive,
# missed word: thyself,
# missed word: wouldst
# missed word: convert’;
# missed word: prognosticate:
# missed word: ‘Thy
# missed word: truth’s
# missed word: beauty’s
# missed word: date.’
# missed word: moment,
# missed word: presenteth
# missed word: nought
# missed word: Whereon
# missed word: comment;
# missed word: increase,
# missed word: self-same
# missed word: sky,
# missed word: Vaunt
# missed word: sap,
# missed word: decrease,
# missed word: memory;
# missed word: inconstant
# missed word: sight,
# missed word: debateth
# missed word: night,
# missed word: you,
# missed word: you,
# missed word: engraft
# missed word: new.
# missed word: wherefore
# missed word: tyrant,
# missed word: Time?
# missed word: rhyme?
# missed word: hours,
# missed word: gardens,
# missed word: unset,
# missed word: flowers,
# missed word: liker
# missed word: counterfeit:
# missed word: repair,
# missed word: this,
# missed word: Time’s
# missed word: pencil,
# missed word: pen,
# missed word: fair,
# missed word: men.
# missed word: yourself,
# missed word: still,
# missed word: live,
# missed word: skill.
# missed word: come,
# missed word: fill’d
# missed word: deserts?
# missed word: life,
# missed word: parts.
# missed word: eyes,
# missed word: graces,
# missed word: ‘This
# missed word: lies;
# missed word: ne’er
# missed word: touch’d
# missed word: faces.’
# missed word: papers,
# missed word: yellow’d
# missed word: age,
# missed word: scorn’d,
# missed word: tongue,
# missed word: term’d
# missed word: poet’s
# missed word: metre
# missed word: song:
# missed word: time,
# missed word: twice,—in
# missed word: it,
# missed word: rhyme.
# missed word: summer’s
# missed word: day?
# missed word: temperate:
# missed word: May,
# missed word: summer’s
# missed word: date:
# missed word: shines,
# missed word: dimm’d,
# missed word: declines,
# missed word: chance,
# missed word: nature’s
# missed word: untrimm’d:
# missed word: fade,
# missed word: ow’st,
# missed word: wander’st
# missed word: shade,
# missed word: grow’st,
# missed word: breathe,
# missed word: see,
# missed word: this,
# missed word: thee.
# missed word: Time,
# missed word: lion’s
# missed word: paws,
# missed word: brood;
# missed word: tiger’s
# missed word: jaws,
# missed word: long-liv’d
# missed word: phoenix,
# missed word: blood;
# missed word: fleets,
# missed word: whate’er
# missed word: wilt,
# missed word: swift-footed
# missed word: Time,
# missed word: sweets;
# missed word: crime:
# missed word: O!
# missed word: love’s
# missed word: brow,
# missed word: pen;
# missed word: beauty’s
# missed word: men.
# missed word: worst,
# missed word: Time;
# missed word: wrong,
# missed word: young.
# missed word: woman’s
# missed word: nature’s
# missed word: painted,
# missed word: thou,
# missed word: passion;
# missed word: woman’s
# missed word: heart,
# missed word: change,
# missed word: women’s
# missed word: fashion:
# missed word: theirs,
# missed word: rolling,
# missed word: gazeth;
# missed word: ‘hues’
# missed word: controlling,
# missed word: men’s
# missed word: women’s
# missed word: amazeth.
# missed word: created;
# missed word: Nature,
# missed word: thee,
# missed word: a-doting,
# missed word: defeated,
# missed word: nothing.
# missed word: prick’d
# missed word: women’s
# missed word: pleasure,
# missed word: love’s
# missed word: treasure.
# missed word: Muse,
# missed word: Stirr’d
# missed word: verse,
# missed word: rehearse,
# missed word: couplement
# missed word: compare.
# missed word: moon,
# missed word: sea’s
# missed word: gems,
# missed word: April’s
# missed word: first-born
# missed word: flowers,
# missed word: rare,
# missed word: heaven’s
# missed word: rondure
# missed word: hems.
# missed word: O!
# missed word: me,
# missed word: love,
# missed word: write,
# missed word: me,
# missed word: mother’s
# missed word: child,
# missed word: fix’d
# missed word: heaven’s
# missed word: air:
# missed word: well;
# missed word: sell.
# missed word: old,
# missed word: date;
# missed word: time’s
# missed word: furrows
# missed word: behold,
# missed word: expiate.
# missed word: thee,
# missed word: seemly
# missed word: raiment
# missed word: heart,
# missed word: live,
# missed word: me:
# missed word: art?
# missed word: O!
# missed word: love,
# missed word: thyself
# missed word: I,
# missed word: myself,
# missed word: will;
# missed word: heart,
# missed word: ill.
# missed word: slain,
# missed word: gav’st
# missed word: again.
# missed word: unperfect
# missed word: stage,
# missed word: part,
# missed word: rage,
# missed word: strength’s
# missed word: heart;
# missed word: I,
# missed word: trust,
# missed word: love’s
# missed word: rite,
# missed word: love’s
# missed word: decay,
# missed word: O’ercharg’d
# missed word: burthen
# missed word: love’s
# missed word: might.
# missed word: O!
# missed word: presagers
# missed word: breast,
# missed word: love,
# missed word: recompense,
# missed word: express’d.
# missed word: O!
# missed word: writ:
# missed word: love’s
# missed word: wit.
# missed word: play’d
# missed word: stell’d,
# missed word: beauty’s
# missed word: heart;
# missed word: ’tis
# missed word: held,
# missed word: painter’s
# missed word: art.
# missed word: skill,
# missed word: pictur’d
# missed word: lies,
# missed word: bosom’s
# missed word: still,
# missed word: eyes.
# missed word: done:
# missed word: shape,
# missed word: breast,
# missed word: where-through
# missed word: peep,
# missed word: thee;
# missed word: art,
# missed word: see,
# missed word: heart.
# missed word: favour
# missed word: honour
# missed word: boast,
# missed word: I,
# missed word: Unlook’d
# missed word: honour
# missed word: most.
# missed word: princes’
# missed word: favourites
# missed word: sun’s
# missed word: eye,
# missed word: buried,
# missed word: die.
# missed word: famoused
# missed word: fight,
# missed word: foil’d,
# missed word: honour
# missed word: quite,
# missed word: toil’d:
# missed word: I,
# missed word: belov’d,
# missed word: remov’d.
# missed word: love,
# missed word: vassalage
# missed word: knit,
# missed word: embassage,
# missed word: duty,
# missed word: wit:
# missed word: great,
# missed word: bare,
# missed word: it,
# missed word: soul’s
# missed word: thought,
# missed word: naked,
# missed word: it:
# missed word: moving,
# missed word: aspect,
# missed word: tatter’d
# missed word: loving,
# missed word: respect:
# missed word: thee;
# missed word: then,
# missed word: mayst
# missed word: me.
# missed word: toil,
# missed word: bed,
# missed word: respose
# missed word: tir’d;
# missed word: mind,
# missed word: body’s
# missed word: work’s
# missed word: expired:
# missed word: thoughts,
# missed word: abide,
# missed word: thee,
# missed word: wide,
# missed word: see:
# missed word: soul’s
# missed word: sightless
# missed word: view,
# missed word: Which,
# missed word: night,
# missed word: beauteous,
# missed word: new.
# missed word: Lo!
# missed word: thus,
# missed word: limbs,
# missed word: mind,
# missed word: thee,
# missed word: myself,
# missed word: find.
# missed word: plight,
# missed word: debarre’d
# missed word: rest?
# missed word: day’s
# missed word: eas’d
# missed word: night,
# missed word: oppress’d,
# missed word: each,
# missed word: either’s
# missed word: reign,
# missed word: me,
# missed word: toil,
# missed word: toil,
# missed word: thee.
# missed word: day,
# missed word: bright,
# missed word: heaven:
# missed word: swart-complexion’d
# missed word: night,
# missed word: twire
# missed word: gild’st
# missed word: even.
# missed word: longer,
# missed word: grief’s
# missed word: stronger.
# missed word: men’s
# missed word: beweep
# missed word: state,
# missed word: bootless
# missed word: cries,
# missed word: myself,
# missed word: fate,
# missed word: hope,
# missed word: Featur’d
# missed word: him,
# missed word: possess’d,
# missed word: man’s
# missed word: art,
# missed word: man’s
# missed word: scope,
# missed word: least;
# missed word: despising,
# missed word: Haply
# missed word: thee,
# missed word: state,
# missed word: earth,
# missed word: heaven’s
# missed word: gate;
# missed word: remember’d
# missed word: kings.
# missed word: past,
# missed word: sought,
# missed word: time’s
# missed word: waste:
# missed word: eye,
# missed word: flow,
# missed word: death’s
# missed word: dateless
# missed word: night,
# missed word: love’s
# missed word: cancell’d
# missed word: woe,
# missed word: vanish’d
# missed word: sight:
# missed word: foregone,
# missed word: o’er
# missed word: fore-bemoaned
# missed word: moan,
# missed word: before.
# missed word: thee,
# missed word: friend,
# missed word: restor’d
# missed word: end.
# missed word: hearts,
# missed word: dead;
# missed word: Love,
# missed word: Love’s
# missed word: parts,
# missed word: buried.
# missed word: stol’n
# missed word: eye,
# missed word: dead,
# missed word: remov’d
# missed word: lie!
# missed word: live,
# missed word: gone,
# missed word: give,
# missed word: alone:
# missed word: lov’d,
# missed word: thee,
# missed word: thou,
# missed word: they,
# missed word: me.
# missed word: well-contented
# missed word: day,
# missed word: churl
# missed word: re-survey
# missed word: lover,
# missed word: bett’ring
# missed word: time,
# missed word: outstripp’d
# missed word: pen,
# missed word: love,
# missed word: rhyme,
# missed word: men.
# missed word: O!
# missed word: vouchsafe
# missed word: thought:
# missed word: ‘Had
# missed word: friend’s
# missed word: age,
# missed word: brought,
# missed word: equipage:
# missed word: prove,
# missed word: I’ll
# missed word: read,
# missed word: love’.
# missed word: eye,
# missed word: green,
# missed word: alchemy;
# missed word: Anon
# missed word: basest
# missed word: face,
# missed word: hide,
# missed word: disgrace:
# missed word: shine,
# missed word: splendour
# missed word: brow;
# missed word: out!
# missed word: alack!
# missed word: mine,
# missed word: mask’d
# missed word: now.
# missed word: disdaineth;
# missed word: heaven’s
# missed word: staineth.
# missed word: didst
# missed word: beauteous
# missed word: day,
# missed word: cloak,
# missed word: o’ertake
# missed word: way,
# missed word: smoke?
# missed word: ’Tis
# missed word: break,
# missed word: storm-beaten
# missed word: face,
# missed word: speak,
# missed word: wound,
# missed word: disgrace:
# missed word: physic
# missed word: grief;
# missed word: repent,
# missed word: loss:
# missed word: offender’s
# missed word: offence’s
# missed word: cross.
# missed word: Ah!
# missed word: sheds,
# missed word: deeds.
# missed word: griev’d
# missed word: done:
# missed word: thorns,
# missed word: mud:
# missed word: sun,
# missed word: bud.
# missed word: faults,
# missed word: this,
# missed word: compare,
# missed word: corrupting,
# missed word: salving
# missed word: amiss,
# missed word: are;
# missed word: sense;
# missed word: advocate,
# missed word: ’gainst
# missed word: commence:
# missed word: hate,
# missed word: accessary
# missed word: be,
# missed word: sourly
# missed word: me.
# missed word: twain,
# missed word: one:
# missed word: remain,
# missed word: help,
# missed word: alone.
# missed word: respect,
# missed word: separable
# missed word: spite,
# missed word: love’s
# missed word: effect,
# missed word: love’s
# missed word: delight.
# missed word: thee,
# missed word: bewailed
# missed word: shame,
# missed word: honour
# missed word: me,
# missed word: honour
# missed word: name:
# missed word: so,
# missed word: sort,
# missed word: mine,
# missed word: report.
# missed word: youth,
# missed word: I,
# missed word: Fortune’s
# missed word: spite,
# missed word: truth;
# missed word: beauty,
# missed word: birth,
# missed word: wealth,
# missed word: wit,
# missed word: all,
# missed word: all,
# missed word: more,
# missed word: parts,
# missed word: sit,
# missed word: engrafted,
# missed word: store:
# missed word: lame,
# missed word: poor,
# missed word: despis’d,
# missed word: suffic’d,
# missed word: live.
# missed word: best,
# missed word: thee:
# missed word: have;
# missed word: me!
# missed word: invent,
# missed word: breathe,
# missed word: pour’st
# missed word: argument,
# missed word: rehearse?
# missed word: O!
# missed word: thyself
# missed word: thanks,
# missed word: aught
# missed word: sight;
# missed word: who’s
# missed word: thee,
# missed word: thyself
# missed word: light?
# missed word: Muse,
# missed word: rhymers
# missed word: invocate;
# missed word: thee,
# missed word: date.
# missed word: days,
# missed word: mine,
# missed word: praise.
# missed word: O!
# missed word: sing,
# missed word: me?
# missed word: bring?
# missed word: is’t
# missed word: thee?
# missed word: this,
# missed word: live,
# missed word: one,
# missed word: deserv’st
# missed word: alone.
# missed word: absence!
# missed word: wouldst
# missed word: prove,
# missed word: leave,
# missed word: love,
# missed word: deceive,
# missed word: teachest
# missed word: twain,
# missed word: remain.
# missed word: loves,
# missed word: love,
# missed word: all;
# missed word: hadst
# missed word: before?
# missed word: love,
# missed word: love,
# missed word: mayst
# missed word: call;
# missed word: thine,
# missed word: hadst
# missed word: more.
# missed word: Then,
# missed word: love,
# missed word: receivest,
# missed word: thee,
# missed word: usest;
# missed word: blam’d,
# missed word: thyself
# missed word: deceivest
# missed word: wilful
# missed word: thyself
# missed word: refusest.
# missed word: robbery,
# missed word: thief,
# missed word: poverty:
# missed word: yet,
# missed word: love’s
# missed word: wrong,
# missed word: hate’s
# missed word: injury.
# missed word: grace,
# missed word: shows,
# missed word: spites
# missed word: foes.
# missed word: commits,
# missed word: heart,
# missed word: beauty,
# missed word: befits,
# missed word: art.
# missed word: art,
# missed word: won,
# missed word: Beauteous
# missed word: art,
# missed word: assail’d;
# missed word: woos,
# missed word: woman’s
# missed word: sourly
# missed word: prevail’d?
# missed word: me!
# missed word: mightst
# missed word: forbear,
# missed word: youth,
# missed word: truth:
# missed word: thee,
# missed word: me.
# missed word: grief,
# missed word: dearly;
# missed word: chief,
# missed word: nearly.
# missed word: ye:
# missed word: her,
# missed word: know’st
# missed word: her;
# missed word: me,
# missed word: her.
# missed word: thee,
# missed word: love’s
# missed word: gain,
# missed word: her,
# missed word: loss;
# missed word: other,
# missed word: twain,
# missed word: cross:
# missed word: here’s
# missed word: joy;
# missed word: one;
# missed word: flattery!
# missed word: alone.
# missed word: wink,
# missed word: see,
# missed word: unrespected;
# missed word: sleep,
# missed word: thee,
# missed word: bright,
# missed word: directed.
# missed word: thou,
# missed word: bright,
# missed word: shadow’s
# missed word: light,
# missed word: unseeing
# missed word: so!
# missed word: would,
# missed word: say,
# missed word: day,
# missed word: sightless
# missed word: stay!
# missed word: thee,
# missed word: me.
# missed word: thought,
# missed word: way;
# missed word: brought,
# missed word: remote,
# missed word: stay.
# missed word: remov’d
# missed word: thee;
# missed word: land,
# missed word: be.
# missed word: But,
# missed word: ah!
# missed word: thought,
# missed word: gone,
# missed word: wrought,
# missed word: time’s
# missed word: moan;
# missed word: nought
# missed word: tears,
# missed word: either’s
# missed word: woe.
# missed word: two,
# missed word: air,
# missed word: thee,
# missed word: abide;
# missed word: thought,
# missed word: desire,
# missed word: present-absent
# missed word: slide.
# missed word: thee,
# missed word: life,
# missed word: four,
# missed word: death,
# missed word: oppress’d
# missed word: melancholy;
# missed word: life’s
# missed word: recur’d
# missed word: return’d
# missed word: thee,
# missed word: again,
# missed word: assur’d,
# missed word: health,
# missed word: me:
# missed word: told,
# missed word: joy;
# missed word: glad,
# missed word: again,
# missed word: sad.
# missed word: war,
# missed word: sight;
# missed word: picture’s
# missed word: bar,
# missed word: right.
# missed word: lie,
# missed word: eyes;
# missed word: deny,
# missed word: lies.
# missed word: impannelled
# missed word: thoughts,
# missed word: heart;
# missed word: eye’s
# missed word: moiety,
# missed word: heart’s
# missed word: part:
# missed word: thus;
# missed word: eye’s
# missed word: part,
# missed word: heart’s
# missed word: right,
# missed word: heart.
# missed word: took,
# missed word: other:
# missed word: famish’d
# missed word: look,
# missed word: smother,
# missed word: love’s
# missed word: feast,
# missed word: heart;
# missed word: heart’s
# missed word: guest,
# missed word: part:
# missed word: So,
# missed word: love,
# missed word: Thyself
# missed word: away,
# missed word: me;
# missed word: canst
# missed word: move,
# missed word: them,
# missed word: thee;
# missed word: Or,
# missed word: sleep,
# missed word: Awakes
# missed word: heart,
# missed word: heart’s
# missed word: eye’s
# missed word: delight.
# missed word: way,
# missed word: thrust,
# missed word: falsehood,
# missed word: trust!
# missed word: thou,
# missed word: are,
# missed word: comfort,
# missed word: grief,
# missed word: dearest,
# missed word: care,
# missed word: thief.
# missed word: lock’d
# missed word: chest,
# missed word: not,
# missed word: art,
# missed word: breast,
# missed word: mayst
# missed word: part;
# missed word: stol’n
# missed word: fear,
# missed word: thievish
# missed word: dear.
# missed word: time,
# missed word: come,
# missed word: defects,
# missed word: sum,
# missed word: Call’d
# missed word: advis’d
# missed word: respects;
# missed word: pass,
# missed word: sun,
# missed word: eye,
# missed word: love,
# missed word: was,
# missed word: gravity;
# missed word: here,
# missed word: desert,
# missed word: hand,
# missed word: uprear,
# missed word: part:
# missed word: laws,
# missed word: cause.
# missed word: way,
# missed word: seek,
# missed word: travel’s
# missed word: end,
# missed word: say,
# missed word: ‘Thus
# missed word: friend!’
# missed word: me,
# missed word: woe,
# missed word: Plods
# missed word: dully
# missed word: on,
# missed word: me,
# missed word: wretch
# missed word: lov’d
# missed word: speed,
# missed word: thee:
# missed word: on,
# missed word: hide,
# missed word: groan,
# missed word: side;
# missed word: mind,
# missed word: onward,
# missed word: behind.
# missed word: offence
# missed word: speed:
# missed word: thence?
# missed word: return,
# missed word: need.
# missed word: O!
# missed word: find,
# missed word: slow?
# missed word: spur,
# missed word: wind,
# missed word: know,
# missed word: pace;
# missed word: desire,
# missed word: perfect’st
# missed word: made,
# missed word: neigh
# missed word: race,
# missed word: love,
# missed word: love,
# missed word: jade:
# missed word: ‘Since
# missed word: going,
# missed word: wilful-slow,
# missed word: I’ll
# missed word: run,
# missed word: go.’
# missed word: rich,
# missed word: key,
# missed word: up-locked
# missed word: treasure,
# missed word: survey,
# missed word: pleasure.
# missed word: rare,
# missed word: Since,
# missed word: set,
# missed word: are,
# missed word: carcanet.
# missed word: chest,
# missed word: hide,
# missed word: special-blest,
# missed word: imprison’d
# missed word: pride.
# missed word: scope,
# missed word: had,
# missed word: triumph;
# missed word: lacked,
# missed word: hope.
# missed word: substance,
# missed word: whereof
# missed word: made,
# missed word: tend?
# missed word: one,
# missed word: one,
# missed word: shade,
# missed word: one,
# missed word: lend.
# missed word: Adonis,
# missed word: you;
# missed word: Helen’s
# missed word: set,
# missed word: new:
# missed word: spring,
# missed word: foison
# missed word: year,
# missed word: show,
# missed word: appear;
# missed word: know.
# missed word: part,
# missed word: none,
# missed word: you,
# missed word: heart.
# missed word: O!
# missed word: beauteous
# missed word: give.
# missed word: fair,
# missed word: odour,
# missed word: live.
# missed word: roses.
# missed word: thorns,
# missed word: summer’s
# missed word: discloses:
# missed word: But,
# missed word: show,
# missed word: unwoo’d,
# missed word: unrespected
# missed word: fade;
# missed word: themselves.
# missed word: so;
# missed word: deaths,
# missed word: odours
# missed word: made:
# missed word: you,
# missed word: beauteous
# missed word: youth,
# missed word: vade,
# missed word: truth.
# missed word: marble,
# missed word: princes,
# missed word: rhyme;
# missed word: unswept
# missed word: stone,
# missed word: besmear’d
# missed word: sluttish
# missed word: time.
# missed word: overturn,
# missed word: broils
# missed word: masonry,
# missed word: sword,
# missed word: war’s
# missed word: memory.
# missed word: ’Gainst
# missed word: death,
# missed word: all-oblivious
# missed word: forth;
# missed word: doom.
# missed word: So,
# missed word: arise,
# missed word: this,
# missed word: lovers’
# missed word: eyes.
# missed word: love,
# missed word: force;
# missed word: appetite,
# missed word: to-day
# missed word: allay’d,
# missed word: To-morrow
# missed word: might:
# missed word: So,
# missed word: love,
# missed word: thou,
# missed word: to-day
# missed word: eyes,
# missed word: fulness,
# missed word: To-morrow
# missed word: again,
# missed word: love,
# missed word: dulness.
# missed word: shore,
# missed word: banks,
# missed word: love,
# missed word: view;
# missed word: winter,
# missed word: care,
# missed word: summer’s
# missed word: welcome,
# missed word: wished,
# missed word: rare.
# missed word: tend,
# missed word: hours,
# missed word: desire?
# missed word: spend;
# missed word: do,
# missed word: require.
# missed word: world-without-end
# missed word: hour,
# missed word: I,
# missed word: sovereign,
# missed word: you,
# missed word: sour,
# missed word: adieu;
# missed word: be,
# missed word: suppose,
# missed word: But,
# missed word: slave,
# missed word: nought
# missed word: Save,
# missed word: are,
# missed word: those.
# missed word: love,
# missed word: will,
# missed word: anything,
# missed word: ill.
# missed word: forbid,
# missed word: slave,
# missed word: pleasure,
# missed word: crave,
# missed word: vassal,
# missed word: leisure!
# missed word: O!
# missed word: suffer,
# missed word: beck,
# missed word: imprison’d
# missed word: liberty;
# missed word: patience,
# missed word: sufferance,
# missed word: check,
# missed word: injury.
# missed word: list,
# missed word: privilage
# missed word: will;
# missed word: self-doing
# missed word: crime.
# missed word: wait,
# missed word: hell,
# missed word: well.
# missed word: new,
# missed word: before,
# missed word: beguil’d,
# missed word: labouring
# missed word: burthen
# missed word: child!
# missed word: O!
# missed word: look,
# missed word: sun,
# missed word: book,
# missed word: done!
# missed word: frame;
# missed word: Wh’r
# missed word: mended,
# missed word: wh’r
# missed word: they,
# missed word: same.
# missed word: O!
# missed word: days,
# missed word: praise.
# missed word: pebbled
# missed word: shore,
# missed word: end;
# missed word: before,
# missed word: contend.
# missed word: Nativity,
# missed word: light,
# missed word: maturity,
# missed word: wherewith
# missed word: crown’d,
# missed word: ’gainst
# missed word: fight,
# missed word: confound.
# missed word: beauty’s
# missed word: brow,
# missed word: nature’s
# missed word: truth,
# missed word: mow:
# missed word: hope,
# missed word: stand.
# missed word: worth,
# missed word: hand.
# missed word: will,
# missed word: night?
# missed word: slumbers
# missed word: broken,
# missed word: sight?
# missed word: send’st
# missed word: pry,
# missed word: me,
# missed word: jealousy?
# missed word: O,
# missed word: no!
# missed word: love,
# missed word: much,
# missed word: great:
# missed word: awake:
# missed word: defeat,
# missed word: sake:
# missed word: I,
# missed word: elsewhere,
# missed word: off,
# missed word: near.
# missed word: self-love
# missed word: possesseth
# missed word: soul,
# missed word: part;
# missed word: remedy,
# missed word: heart.
# missed word: Methinks
# missed word: mine,
# missed word: true,
# missed word: account;
# missed word: define,
# missed word: surmount.
# missed word: Beated
# missed word: chopp’d
# missed word: antiquity,
# missed word: self-love
# missed word: read;
# missed word: self-loving
# missed word: iniquity.
# missed word: ’Tis
# missed word: thee,
# missed word: myself,
# missed word: praise,
# missed word: days.
# missed word: now,
# missed word: Time’s
# missed word: crush’d
# missed word: o’erworn;
# missed word: drain’d
# missed word: fill’d
# missed word: wrinkles;
# missed word: travell’d
# missed word: age’s
# missed word: steepy
# missed word: night;
# missed word: whereof
# missed word: he’s
# missed word: vanishing,
# missed word: sight,
# missed word: spring;
# missed word: age’s
# missed word: knife,
# missed word: love’s
# missed word: beauty,
# missed word: lover’s
# missed word: life:
# missed word: seen,
# missed word: live,
# missed word: green.
# missed word: Time’s
# missed word: defac’d
# missed word: rich-proud
# missed word: outworn
# missed word: age;
# missed word: down-raz’d,
# missed word: rage;
# missed word: shore,
# missed word: main,
# missed word: loss,
# missed word: store;
# missed word: state,
# missed word: confounded,
# missed word: decay;
# missed word: ruminate:
# missed word: away.
# missed word: have,
# missed word: lose.
# missed word: brass,
# missed word: stone,
# missed word: earth,
# missed word: sea,
# missed word: o’ersways
# missed word: power,
# missed word: plea,
# missed word: flower?
# missed word: O!
# missed word: summer’s
# missed word: out,
# missed word: wrackful
# missed word: days,
# missed word: stout,
# missed word: decays?
# missed word: meditation!
# missed word: where,
# missed word: alack,
# missed word: Time’s
# missed word: Time’s
# missed word: hid?
# missed word: back?
# missed word: forbid?
# missed word: O!
# missed word: none,
# missed word: might,
# missed word: bright.
# missed word: these,
# missed word: cry:
# missed word: born,
# missed word: trimm’d
# missed word: jollity,
# missed word: forsworn,
# missed word: honour
# missed word: shamefully
# missed word: misplac’d,
# missed word: strumpeted,
# missed word: disgrac’d,
# missed word: tongue-tied
# missed word: authority,
# missed word: folly,
# missed word: doctor-like,
# missed word: skill,
# missed word: miscall’d
# missed word: simplicity,
# missed word: ill:
# missed word: Tir’d
# missed word: these,
# missed word: gone,
# missed word: that,
# missed word: die,
# missed word: alone.
# missed word: Ah!
# missed word: wherefore
# missed word: live,
# missed word: impiety,
# missed word: achieve,
# missed word: society?
# missed word: cheek,
# missed word: hue?
# missed word: shadow,
# missed word: true?
# missed word: live,
# missed word: is,
# missed word: Beggar’d
# missed word: veins?
# missed word: his,
# missed word: many,
# missed word: gains.
# missed word: O!
# missed word: stores,
# missed word: since,
# missed word: bad.
# missed word: outworn,
# missed word: now,
# missed word: born,
# missed word: brow;
# missed word: dead,
# missed word: sepulchres,
# missed word: away,
# missed word: head;
# missed word: beauty’s
# missed word: gay:
# missed word: seen,
# missed word: ornament,
# missed word: true,
# missed word: another’s
# missed word: green,
# missed word: new;
# missed word: store,
# missed word: yore.
# missed word: world’s
# missed word: mend;
# missed word: tongues,
# missed word: souls,
# missed word: due,
# missed word: truth,
# missed word: commend.
# missed word: crown’d;
# missed word: tongues,
# missed word: own,
# missed word: shown.
# missed word: mind,
# missed word: deeds;
# missed word: churls
# missed word: thoughts,
# missed word: kind,
# missed word: weeds:
# missed word: odour
# missed word: matcheth
# missed word: show,
# missed word: this,
# missed word: grow.
# missed word: blam’d
# missed word: defect,
# missed word: slander’s
# missed word: fair;
# missed word: suspect,
# missed word: heaven’s
# missed word: air.
# missed word: good,
# missed word: woo’d
# missed word: time;
# missed word: love,
# missed word: present’st
# missed word: prime.
# missed word: assail’d,
# missed word: charg’d;
# missed word: praise,
# missed word: envy,
# missed word: enlarg’d,
# missed word: mask’d
# missed word: show,
# missed word: shouldst
# missed word: owe.
# missed word: vilest
# missed word: dwell:
# missed word: Nay,
# missed word: line,
# missed word: it,
# missed word: so,
# missed word: forgot,
# missed word: woe.
# missed word: if,
# missed word: say,
# missed word: verse,
# missed word: clay,
# missed word: rehearse;
# missed word: decay;
# missed word: moan,
# missed word: gone.
# missed word: O!
# missed word: me,
# missed word: death,
# missed word: love,
# missed word: quite,
# missed word: prove;
# missed word: lie,
# missed word: desert,
# missed word: impart:
# missed word: O!
# missed word: untrue,
# missed word: is,
# missed word: you.
# missed word: forth,
# missed word: you,
# missed word: worth.
# missed word: mayst
# missed word: leaves,
# missed word: none,
# missed word: few,
# missed word: cold,
# missed word: ruin’d
# missed word: choirs,
# missed word: sang.
# missed word: see’st
# missed word: fadeth
# missed word: west;
# missed word: away,
# missed word: Death’s
# missed word: self,
# missed word: rest.
# missed word: see’st
# missed word: fire,
# missed word: lie,
# missed word: death-bed,
# missed word: whereon
# missed word: expire,
# missed word: Consum’d
# missed word: nourish’d
# missed word: by.
# missed word: perceiv’st,
# missed word: strong,
# missed word: well,
# missed word: long.
# missed word: contented:
# missed word: away,
# missed word: interest,
# missed word: stay.
# missed word: reviewest
# missed word: this,
# missed word: thee:
# missed word: earth,
# missed word: due;
# missed word: thine,
# missed word: me:
# missed word: life,
# missed word: worms,
# missed word: dead;
# missed word: wretch’s
# missed word: knife,
# missed word: remembered.
# missed word: contains,
# missed word: this,
# missed word: remains.
# missed word: life,
# missed word: sweet-season’d
# missed word: ground;
# missed word: ’twixt
# missed word: found.
# missed word: enjoyer,
# missed word: anon
# missed word: filching
# missed word: treasure;
# missed word: alone,
# missed word: better’d
# missed word: pleasure:
# missed word: sight,
# missed word: look;
# missed word: delight,
# missed word: had,
# missed word: took.
# missed word: day,
# missed word: gluttoning
# missed word: all,
# missed word: away.
# missed word: pride,
# missed word: change?
# missed word: new-found
# missed word: methods,
# missed word: strange?
# missed word: one,
# missed word: same,
# missed word: weed,
# missed word: name,
# missed word: birth,
# missed word: proceed?
# missed word: O!
# missed word: you,
# missed word: argument;
# missed word: new,
# missed word: spent:
# missed word: old,
# missed word: told.
# missed word: wear,
# missed word: waste;
# missed word: mind’s
# missed word: bear,
# missed word: book,
# missed word: mayst
# missed word: taste.
# missed word: memory;
# missed word: dial’s
# missed word: mayst
# missed word: Time’s
# missed word: thievish
# missed word: eternity.
# missed word: Look!
# missed word: contain,
# missed word: blanks,
# missed word: nursed,
# missed word: deliver’d
# missed word: brain,
# missed word: mind.
# missed word: offices,
# missed word: look,
# missed word: book.
# missed word: Muse,
# missed word: poesy
# missed word: disperse.
# missed word: eyes,
# missed word: fly,
# missed word: learned’s
# missed word: majesty.
# missed word: compile,
# missed word: thine,
# missed word: thee:
# missed word: others’
# missed word: style,
# missed word: be;
# missed word: art,
# missed word: learning,
# missed word: ignorance.
# missed word: aid,
# missed word: grace;
# missed word: decay’d,
# missed word: place.
# missed word: grant,
# missed word: love,
# missed word: pen;
# missed word: of,
# missed word: again.
# missed word: virtue,
# missed word: behaviour;
# missed word: give,
# missed word: cheek:
# missed word: thee,
# missed word: live.
# missed word: say,
# missed word: thee,
# missed word: thyself
# missed word: pay.
# missed word: write,
# missed word: name,
# missed word: might,
# missed word: tongue-tied
# missed word: fame!
# missed word: worth,
# missed word: is,
# missed word: bear,
# missed word: bark,
# missed word: his,
# missed word: appear.
# missed word: shallowest
# missed word: afloat,
# missed word: soundless
# missed word: ride;
# missed word: Or,
# missed word: wrack’d,
# missed word: boat,
# missed word: building,
# missed word: pride:
# missed word: away,
# missed word: this:
# missed word: decay.
# missed word: make,
# missed word: rotten;
# missed word: take,
# missed word: forgotten.
# missed word: have,
# missed word: I,
# missed word: gone,
# missed word: die:
# missed word: grave,
# missed word: men’s
# missed word: lie.
# missed word: verse,
# missed word: o’er-read;
# missed word: be,
# missed word: rehearse,
# missed word: breathers
# missed word: dead;
# missed word: live,
# missed word: pen,
# missed word: breathes,
# missed word: men.
# missed word: Muse,
# missed word: mayst
# missed word: attaint
# missed word: o’erlook
# missed word: subject,
# missed word: book.
# missed word: hue,
# missed word: praise;
# missed word: time-bettering
# missed word: days.
# missed word: so,
# missed word: love;
# missed word: devis’d,
# missed word: lend,
# missed word: fair,
# missed word: sympathiz’d
# missed word: words,
# missed word: true-telling
# missed word: friend;
# missed word: us’d
# missed word: blood;
# missed word: abus’d.
# missed word: need,
# missed word: set;
# missed word: found,
# missed word: found,
# missed word: poet’s
# missed word: debt:
# missed word: report,
# missed word: yourself,
# missed word: extant,
# missed word: short,
# missed word: worth,
# missed word: grow.
# missed word: impute,
# missed word: dumb;
# missed word: mute,
# missed word: life,
# missed word: tomb.
# missed word: devise.
# missed word: most,
# missed word: more,
# missed word: praise:
# missed word: you,
# missed word: immured
# missed word: grew.
# missed word: glory;
# missed word: you,
# missed word: you,
# missed word: dignifies
# missed word: story,
# missed word: writ,
# missed word: clear,
# missed word: wit,
# missed word: where.
# missed word: beauteous
# missed word: curse,
# missed word: praise,
# missed word: worse.
# missed word: tongue-tied
# missed word: still,
# missed word: compil’d,
# missed word: quill,
# missed word: fil’d.
# missed word: thoughts,
# missed word: words,
# missed word: unlettered
# missed word: ‘Amen’
# missed word: affords,
# missed word: polish’d
# missed word: well-refined
# missed word: pen.
# missed word: praised,
# missed word: ‘’tis
# missed word: so,
# missed word: ’tis
# missed word: true,’
# missed word: more;
# missed word: thought,
# missed word: you,
# missed word: hindmost,
# missed word: before.
# missed word: others,
# missed word: respect,
# missed word: thoughts,
# missed word: effect.
# missed word: verse,
# missed word: you,
# missed word: inhearse,
# missed word: grew?
# missed word: spirit,
# missed word: write,
# missed word: pitch,
# missed word: dead?
# missed word: No,
# missed word: he,
# missed word: compeers
# missed word: aid,
# missed word: astonished.
# missed word: He,
# missed word: intelligence,
# missed word: boast;
# missed word: thence:
# missed word: fill’d
# missed word: line,
# missed word: matter;
# missed word: mine.
# missed word: Farewell!
# missed word: possessing,
# missed word: know’st
# missed word: estimate,
# missed word: releasing;
# missed word: determinate.
# missed word: granting?
# missed word: deserving?
# missed word: wanting,
# missed word: swerving.
# missed word: Thyself
# missed word: gav’st,
# missed word: knowing,
# missed word: gav’st
# missed word: it,
# missed word: mistaking;
# missed word: gift,
# missed word: growing,
# missed word: again,
# missed word: making.
# missed word: thee,
# missed word: flatter,
# missed word: king,
# missed word: matter.
# missed word: dispos’d
# missed word: light,
# missed word: scorn,
# missed word: side,
# missed word: I’ll
# missed word: fight,
# missed word: virtuous,
# missed word: forsworn.
# missed word: weakness,
# missed word: acquainted,
# missed word: conceal’d,
# missed word: attainted;
# missed word: glory:
# missed word: too;
# missed word: thee,
# missed word: do,
# missed word: vantage,
# missed word: double-vantage
# missed word: me.
# missed word: love,
# missed word: belong,
# missed word: right,
# missed word: wrong.
# missed word: didst
# missed word: fault,
# missed word: offence:
# missed word: lameness,
# missed word: halt,
# missed word: defence.
# missed word: canst
# missed word: ill,
# missed word: change,
# missed word: I’ll
# missed word: disgrace;
# missed word: will,
# missed word: strangle,
# missed word: strange;
# missed word: walks;
# missed word: dwell,
# missed word: I,
# missed word: profane,
# missed word: wrong,
# missed word: haply
# missed word: tell.
# missed word: thee,
# missed word: I’ll
# missed word: debate,
# missed word: ne’er
# missed word: hate.
# missed word: wilt;
# missed word: ever,
# missed word: now;
# missed word: Now,
# missed word: cross,
# missed word: fortune,
# missed word: bow,
# missed word: after-loss:
# missed word: Ah!
# missed word: not,
# missed word: ’scap’d
# missed word: sorrow,
# missed word: rearward
# missed word: conquer’d
# missed word: woe;
# missed word: morrow,
# missed word: purpos’d
# missed word: overthrow.
# missed word: me,
# missed word: last,
# missed word: griefs
# missed word: spite,
# missed word: come:
# missed word: fortune’s
# missed word: might;
# missed word: woe,
# missed word: woe,
# missed word: Compar’d
# missed word: thee,
# missed word: so.
# missed word: birth,
# missed word: skill,
# missed word: wealth,
# missed word: body’s
# missed word: force,
# missed word: new-fangled
# missed word: ill;
# missed word: hounds,
# missed word: horse;
# missed word: humour
# missed word: pleasure,
# missed word: rest:
# missed word: measure,
# missed word: best.
# missed word: me,
# missed word: wealth,
# missed word: garments’
# missed word: costs,
# missed word: be;
# missed word: thee,
# missed word: men’s
# missed word: boast:
# missed word: alone,
# missed word: mayst
# missed word: away,
# missed word: make.
# missed word: thyself
# missed word: away,
# missed word: mine;
# missed word: stay,
# missed word: thine.
# missed word: wrongs,
# missed word: end.
# missed word: humour
# missed word: depend:
# missed word: canst
# missed word: inconstant
# missed word: mind,
# missed word: lie.
# missed word: O!
# missed word: find,
# missed word: love,
# missed word: die!
# missed word: what’s
# missed word: blessed-fair
# missed word: blot?
# missed word: mayst
# missed word: false,
# missed word: not.
# missed word: live,
# missed word: true,
# missed word: husband;
# missed word: love’s
# missed word: me,
# missed word: alter’d
# missed word: new;
# missed word: me,
# missed word: place:
# missed word: eye,
# missed word: change.
# missed word: many’s
# missed word: looks,
# missed word: heart’s
# missed word: moods,
# missed word: frowns,
# missed word: strange.
# missed word: dwell;
# missed word: Whate’er
# missed word: thoughts,
# missed word: heart’s
# missed word: be,
# missed word: thence,
# missed word: tell.
# missed word: Eve’s
# missed word: grow,
# missed word: show!
# missed word: hurt,
# missed word: none,
# missed word: show,
# missed word: Who,
# missed word: others,
# missed word: stone,
# missed word: Unmoved,
# missed word: cold,
# missed word: slow;
# missed word: heaven’s
# missed word: graces,
# missed word: nature’s
# missed word: expense;
# missed word: faces,
# missed word: Others,
# missed word: excellence.
# missed word: summer’s
# missed word: sweet,
# missed word: itself,
# missed word: die,
# missed word: meet,
# missed word: basest
# missed word: outbraves
# missed word: dignity:
# missed word: sourest
# missed word: deeds;
# missed word: fester,
# missed word: weeds.
# missed word: Which,
# missed word: rose,
# missed word: name!
# missed word: O!
# missed word: enclose.
# missed word: days,
# missed word: sport,
# missed word: dispraise,
# missed word: praise;
# missed word: name,
# missed word: report.
# missed word: O!
# missed word: thee,
# missed word: beauty’s
# missed word: see!
# missed word: heed,
# missed word: heart,
# missed word: privilege;
# missed word: ill-us’d
# missed word: edge.
# missed word: youth,
# missed word: wantonness;
# missed word: sport;
# missed word: lov’d
# missed word: less:
# missed word: mak’st
# missed word: resort.
# missed word: throned
# missed word: basest
# missed word: esteem’d,
# missed word: translated,
# missed word: deem’d.
# missed word: betray,
# missed word: translate!
# missed word: gazers
# missed word: mightst
# missed word: away,
# missed word: wouldst
# missed word: state!
# missed word: so;
# missed word: sort,
# missed word: As,
# missed word: mine,
# missed word: report.
# missed word: thee,
# missed word: year!
# missed word: freezings
# missed word: felt,
# missed word: seen!
# missed word: December’s
# missed word: bareness
# missed word: everywhere!
# missed word: summer’s
# missed word: time;
# missed word: autumn,
# missed word: increase,
# missed word: prime,
# missed word: widow’d
# missed word: wombs
# missed word: lords’
# missed word: decease:
# missed word: seem’d
# missed word: orphans,
# missed word: unfather’d
# missed word: fruit;
# missed word: thee,
# missed word: And,
# missed word: away,
# missed word: mute:
# missed word: Or,
# missed word: sing,
# missed word: ’tis
# missed word: cheer,
# missed word: pale,
# missed word: winter’s
# missed word: near.
# missed word: spring,
# missed word: proud-pied
# missed word: April,
# missed word: dress’d
# missed word: trim,
# missed word: thing,
# missed word: laugh’d
# missed word: leap’d
# missed word: him.
# missed word: birds,
# missed word: odour
# missed word: hue,
# missed word: summer’s
# missed word: tell,
# missed word: grew:
# missed word: lily’s
# missed word: white,
# missed word: rose;
# missed word: sweet,
# missed word: delight,
# missed word: you,
# missed word: those.
# missed word: seem’d
# missed word: still,
# missed word: away,
# missed word: play.
# missed word: chide:
# missed word: thief,
# missed word: didst
# missed word: smells,
# missed word: love’s
# missed word: breath?
# missed word: love’s
# missed word: dy’d.
# missed word: hand,
# missed word: stol’n
# missed word: hair;
# missed word: fearfully
# missed word: stand,
# missed word: shame,
# missed word: despair;
# missed word: third,
# missed word: white,
# missed word: stol’n
# missed word: both,
# missed word: annex’d
# missed word: breath;
# missed word: But,
# missed word: theft,
# missed word: death.
# missed word: noted,
# missed word: see,
# missed word: sweet,
# missed word: colour
# missed word: stol’n
# missed word: thee.
# missed word: forget’st
# missed word: long,
# missed word: might?
# missed word: Spend’st
# missed word: song,
# missed word: light?
# missed word: Muse,
# missed word: redeem,
# missed word: spent;
# missed word: argument.
# missed word: Rise,
# missed word: resty
# missed word: Muse,
# missed word: love’s
# missed word: survey,
# missed word: there;
# missed word: any,
# missed word: decay,
# missed word: time’s
# missed word: where.
# missed word: life,
# missed word: prevent’st
# missed word: knife.
# missed word: dy’d?
# missed word: depends;
# ...
# missed word: thee;
# missed word: ill-wresting
# missed word: bad,
# missed word: slanderers
# missed word: be.
# missed word: so,
# missed word: belied,
# missed word: straight,
# missed word: wide.
# missed word: eyes,
# missed word: note;
# missed word: ’tis
# missed word: despise,
# missed word: Who,
# missed word: view,
# missed word: dote.
# missed word: tongue’s
# missed word: delighted;
# missed word: feeling,
# missed word: prone,
# missed word: taste,
# missed word: smell,
# missed word: alone:
# missed word: thee,
# missed word: unsway’d
# missed word: man,
# missed word: heart’s
# missed word: wretch
# missed word: be:
# missed word: gain,
# missed word: pain.
# missed word: sin,
# missed word: hate,
# missed word: sin,
# missed word: loving:
# missed word: O!
# missed word: state,
# missed word: reproving;
# missed word: Or,
# missed word: do,
# missed word: thine,
# missed word: profan’d
# missed word: seal’d
# missed word: mine,
# missed word: Robb’d
# missed word: others’
# missed word: beds’
# missed word: rents.
# missed word: thee,
# missed word: lov’st
# missed word: importune
# missed word: thee:
# missed word: heart,
# missed word: that,
# missed word: grows,
# missed word: be.
# missed word: hide,
# missed word: self-example
# missed word: mayst
# missed word: denied!
# missed word: Lo,
# missed word: feather’d
# missed word: away,
# missed word: babe,
# missed word: stay;
# missed word: chase,
# missed word: face,
# missed word: prizing
# missed word: infant’s
# missed word: discontent;
# missed word: runn’st
# missed word: thee,
# missed word: behind;
# missed word: hope,
# missed word: me,
# missed word: mother’s
# missed word: part,
# missed word: me,
# missed word: kind;
# missed word: mayst
# missed word: ‘Will,’
# missed word: still.
# missed word: despair,
# missed word: still:
# missed word: fair,
# missed word: worser
# missed word: colour’d
# missed word: ill.
# missed word: hell,
# missed word: evil,
# missed word: Tempteth
# missed word: side,
# missed word: devil,
# missed word: pride.
# missed word: turn’d
# missed word: fiend,
# missed word: may,
# missed word: tell;
# missed word: me,
# missed word: friend,
# missed word: another’s
# missed word: hell:
# missed word: ne’er
# missed word: know,
# missed word: doubt,
# missed word: out.
# missed word: Love’s
# missed word: make,
# missed word: ‘I
# missed word: hate’,
# missed word: languish’d
# missed word: sake:
# missed word: state,
# missed word: come,
# missed word: us’d
# missed word: doom;
# missed word: greet;
# missed word: ‘I
# missed word: hate’
# missed word: alter’d
# missed word: end,
# missed word: day,
# missed word: night,
# missed word: away.
# missed word: ‘I
# missed word: hate’,
# missed word: threw,
# missed word: sav’d
# missed word: life,
# missed word: ‘not
# missed word: you’.
# missed word: soul,
# missed word: earth,
# missed word: array,
# missed word: dearth,
# missed word: gay?
# missed word: cost,
# missed word: lease,
# missed word: spend?
# missed word: worms,
# missed word: inheritors
# missed word: excess,
# missed word: charge?
# missed word: body’s
# missed word: end?
# missed word: soul,
# missed word: servant’s
# missed word: loss,
# missed word: store;
# missed word: dross;
# missed word: fed,
# missed word: more:
# missed word: Death,
# missed word: men,
# missed word: dead,
# missed word: there’s
# missed word: then.
# missed word: still,
# missed word: nurseth
# missed word: disease;
# missed word: ill,
# missed word: please.
# missed word: reason,
# missed word: love,
# missed word: kept,
# missed word: me,
# missed word: death,
# missed word: physic
# missed word: except.
# missed word: am,
# missed word: care,
# missed word: frantic-mad
# missed word: unrest;
# missed word: madmen’s
# missed word: are,
# missed word: express’d;
# missed word: fair,
# missed word: bright,
# missed word: hell,
# missed word: night.
# missed word: me!
# missed word: head,
# missed word: sight;
# missed word: Or,
# missed word: have,
# missed word: fled,
# missed word: censures
# missed word: aright?
# missed word: whereon
# missed word: dote,
# missed word: so?
# missed word: not,
# missed word: Love’s
# missed word: men’s:
# missed word: no,
# missed word: it?
# missed word: O!
# missed word: Love’s
# missed word: true,
# missed word: tears?
# missed word: then,
# missed word: view;
# missed word: not,
# missed word: clears.
# missed word: Love!
# missed word: keep’st
# missed word: blind,
# missed word: well-seeing
# missed word: find.
# missed word: Canst
# missed word: thou,
# missed word: cruel!
# missed word: not,
# missed word: partake?
# missed word: thee,
# missed word: self,
# missed word: tyrant,
# missed word: sake?
# missed word: hateth
# missed word: friend,
# missed word: frown’st
# missed word: upon,
# missed word: Nay,
# missed word: lour’st
# missed word: me,
# missed word: moan?
# missed word: respect,
# missed word: despise,
# missed word: defect,
# missed word: eyes?
# missed word: But,
# missed word: love,
# missed word: on,
# missed word: mind;
# missed word: lov’st,
# missed word: blind.
# missed word: O!
# missed word: might,
# missed word: insufficiency
# missed word: sway?
# missed word: sight,
# missed word: day?
# missed word: ill,
# missed word: warrantise
# missed word: skill,
# missed word: That,
# missed word: mind,
# missed word: exceeds?
# missed word: more,
# missed word: hate?
# missed word: O!
# missed word: abhor,
# missed word: shouldst
# missed word: state:
# missed word: unworthiness
# missed word: rais’d
# missed word: me,
# missed word: belov’d
# missed word: thee.
# missed word: is,
# missed word: love?
# missed word: Then,
# missed word: cheater,
# missed word: amiss,
# missed word: prove:
# missed word: For,
# missed word: me,
# missed word: body’s
# missed word: treason;
# missed word: love;
# missed word: reason,
# missed word: thee,
# missed word: prize.
# missed word: pride,
# missed word: be,
# missed word: affairs,
# missed word: side.
# missed word: ‘love,’
# missed word: fall.
# missed word: know’st
# missed word: forsworn,
# missed word: forsworn,
# missed word: swearing;
# missed word: bed-vow
# missed word: broke,
# missed word: torn,
# missed word: bearing:
# missed word: oaths’
# missed word: thee,
# missed word: twenty?
# missed word: perjur’d
# missed word: most;
# missed word: thee,
# missed word: lost:
# missed word: kindness,
# missed word: love,
# missed word: truth,
# missed word: constancy;
# missed word: And,
# missed word: thee,
# missed word: blindness,
# missed word: see;
# missed word: fair;
# missed word: I,
# missed word: lie.
# missed word: asleep:
# missed word: Dian’s
# missed word: found,
# missed word: love-kindling
# missed word: valley-fountain
# missed word: ground;
# missed word: borrow’d
# missed word: Love,
# missed word: dateless
# missed word: heat,
# missed word: endure,
# missed word: bath,
# missed word: cure.
# missed word: mistress’
# missed word: Love’s
# missed word: new-fired,
# missed word: breast;
# missed word: I,
# missed word: withal,
# missed word: desired,
# missed word: thither
# missed word: hied,
# missed word: distemper’d
# missed word: guest,
# missed word: cure,
# missed word: fire;
# missed word: mistress’
# missed word: eyes.
# missed word: Love-god
# missed word: asleep,
# missed word: heart-inflaming
# missed word: brand,
# missed word: vow’d
# missed word: by;
# missed word: votary
# missed word: warm’d;
# missed word: Was,
# missed word: sleeping,
# missed word: disarm’d.
# missed word: quenched
# missed word: by,
# missed word: Love’s
# missed word: perpetual,
# missed word: remedy,
# missed word: diseased;
# missed word: I,
# missed word: mistress’
# missed word: thrall,
# missed word: prove,
# missed word: Love’s
# missed word: water,
# missed word: love.
# missed word: ***
# missed word: EBOOK
# missed word: ***
# missed word: one—the
# missed word: U.S.
# missed word: works,
# missed word: (and
# missed word: you!)
# missed word: royalties.
# missed word: rules,
# missed word: license,
# missed word: Gutenberg™
# missed word: GUTENBERG™
# missed word: trademark.
# missed word: trademark,
# missed word: eBook,
# missed word: license,
# missed word: trademark.
# missed word: eBook,
# missed word: easy.
# missed word: eBook
# missed word: works,
# missed word: reports,
# missed word: research.
# missed word: eBooks
# missed word: away—you
# missed word: eBooks
# missed word: U.S.
# missed word: law.
# missed word: license,
# missed word: redistribution.
# missed word: Gutenberg™
# missed word: works,
# missed word: (or
# missed word: “Project
# missed word: Gutenberg”),
# missed word: Gutenberg™
# missed word: www.gutenberg.org/license.
# missed word: 1.
# missed word: Gutenberg™
# missed word: 1.A.
# missed word: Gutenberg™
# missed word: work,
# missed word: read,
# missed word: understand,
# missed word: (trademark/copyright)
# missed word: agreement.
# missed word: agreement,
# missed word: Gutenberg™
# missed word: possession.
# missed word: Gutenberg™
# missed word: agreement,
# missed word: 1.E.8.
# missed word: 1.B.
# missed word: “Project
# missed word: Gutenberg”
# missed word: trademark.
# missed word: agreement.
# missed word: Gutenberg™
# missed word: agreement.
# missed word: 1.C
# missed word: below.
# missed word: Gutenberg™
# missed word: Gutenberg™
# missed word: works.
# missed word: 1.E
# missed word: below.
# missed word: 1.C.
# missed word: (“the
# missed word: Foundation”
# missed word: PGLAF),
# missed word: Gutenberg™
# missed word: works.
# missed word: States.
# missed word: States,
# missed word: copying,
# missed word: distributing,
# missed word: performing,
# missed word: removed.
# missed word: course,
# missed word: Gutenberg™
# missed word: Gutenberg™
# missed word: Gutenberg™
# missed word: work.
# missed word: Gutenberg™
# missed word: others.
# missed word: 1.D.
# missed word: work.
# missed word: change.
# missed word: States,
# missed word: downloading,
# missed word: copying,
# missed word: displaying,
# missed word: performing,
# missed word: Gutenberg™
# missed word: work.
# missed word: States.
# missed word: 1.E.
# missed word: Gutenberg:
# missed word: 1.E.1.
# missed word: sentence,
# missed word: to,
# missed word: to,
# missed word: Gutenberg™
# missed word: Gutenberg™
# missed word: (any
# missed word: “Project
# missed word: Gutenberg”
# missed word: appears,
# missed word: “Project
# missed word: Gutenberg”
# missed word: associated)
# missed word: accessed,
# missed word: displayed,
# missed word: performed,
# missed word: viewed,
# missed word: distributed:
# missed word: eBook
# missed word: whatsoever.
# missed word: it,
# missed word: re-use
# missed word: eBook
# missed word: www.gutenberg.org.
# missed word: States,
# missed word: eBook.
# missed word: 1.E.2.
# missed word: Gutenberg™
# missed word: U.S.
# missed word: (does
# missed word: holder),
# missed word: charges.
# missed word: “Project
# missed word: Gutenberg”
# missed word: work,
# missed word: 1.E.1
# missed word: 1.E.7
# missed word: Gutenberg™
# missed word: 1.E.8
# missed word: 1.E.9.
# missed word: 1.E.3.
# missed word: Gutenberg™
# missed word: holder,
# missed word: 1.E.1
# missed word: 1.E.7
# missed word: holder.
# missed word: Gutenberg™
# missed word: work.
# missed word: 1.E.4.
# missed word: unlink
# missed word: Gutenberg™
# missed word: work,
# missed word: Gutenberg™.
# missed word: 1.E.5.
# missed word: copy,
# missed word: display,
# missed word: perform,
# missed word: work,
# missed word: work,
# missed word: 1.E.1
# missed word: 1.E.6.
# missed word: binary,
# missed word: compressed,
# missed word: up,
# missed word: nonproprietary
# missed word: form,
# missed word: form.
# missed word: However,
# missed word: Gutenberg™
# missed word: “Plain
# missed word: ASCII”
# missed word: Gutenberg™
# missed word: (www.gutenberg.org),
# missed word: must,
# missed word: cost,
# missed word: user,
# missed word: copy,
# missed word: copy,
# missed word: request,
# missed word: “Plain
# missed word: ASCII”
# missed word: form.
# missed word: Gutenberg™
# missed word: 1.E.1.
# missed word: 1.E.7.
# missed word: to,
# missed word: viewing,
# missed word: displaying,
# missed word: performing,
# missed word: Gutenberg™
# missed word: 1.E.8
# missed word: 1.E.9.
# missed word: 1.E.8.
# missed word: Gutenberg™
# missed word: •
# missed word: 20%
# missed word: Gutenberg™
# missed word: taxes.
# missed word: Gutenberg™
# missed word: trademark,
# missed word: Foundation.
# missed word: 60
# missed word: (or
# missed word: prepare)
# missed word: returns.
# missed word: 4,
# missed word: “Information
# missed word: Foundation.”
# missed word: •
# missed word: (or
# missed word: e-mail)
# missed word: 30
# missed word: s/he
# missed word: Gutenberg™
# missed word: License.
# missed word: Gutenberg™
# missed word: •
# missed word: provide,
# missed word: 1.F.3,
# missed word: copy,
# missed word: 90
# missed word: work.
# missed word: •
# missed word: Gutenberg™
# missed word: works.
# missed word: 1.E.9.
# missed word: Gutenberg™
# missed word: agreement,
# missed word: Foundation,
# missed word: Gutenberg™
# missed word: trademark.
# missed word: 3
# missed word: below.
# missed word: 1.F.1.
# missed word: identify,
# missed word: on,
# missed word: U.S.
# missed word: Gutenberg™
# missed word: collection.
# missed word: efforts,
# missed word: Gutenberg™
# missed word: works,
# missed word: stored,
# missed word: “Defects,”
# missed word: as,
# missed word: to,
# missed word: incomplete,
# missed word: data,
# missed word: errors,
# missed word: infringement,
# missed word: medium,
# missed word: virus,
# missed word: equipment.
# missed word: 1.F.2.
# missed word: WARRANTY,
# missed word: -
# missed word: “Right
# missed word: Refund”
# missed word: 1.F.3,
# missed word: Foundation,
# missed word: Gutenberg™
# missed word: trademark,
# missed word: Gutenberg™
# missed word: agreement,
# missed word: damages,
# missed word: expenses,
# missed word: fees.
# missed word: NEGLIGENCE,
# missed word: LIABILITY,
# missed word: 1.F.3.
# missed word: FOUNDATION,
# missed word: OWNER,
# missed word: ACTUAL,
# missed word: DIRECT,
# missed word: INDIRECT,
# missed word: CONSEQUENTIAL,
# missed word: 1.F.3.
# missed word: -
# missed word: 90
# missed word: it,
# missed word: (if
# missed word: any)
# missed word: from.
# missed word: medium,
# missed word: explanation.
# missed word: refund.
# missed word: electronically,
# missed word: refund.
# missed word: defective,
# missed word: problem.
# missed word: 1.F.4.
# missed word: 1.F.3,
# missed word: ‘AS-IS’,
# missed word: KIND,
# missed word: IMPLIED,
# missed word: MERCHANTABILITY
# missed word: PURPOSE.
# missed word: 1.F.5.
# missed word: damages.
# missed word: agreement,
# missed word: law.
# missed word: invalidity
# missed word: unenforceability
# missed word: provisions.
# missed word: 1.F.6.
# missed word: -
# missed word: Foundation,
# missed word: owner,
# missed word: Foundation,
# missed word: Gutenberg™
# missed word: agreement,
# missed word: production,
# missed word: Gutenberg™
# missed word: works,
# missed word: liability,
# missed word: expenses,
# missed word: fees,
# missed word: occur:
# missed word: (a)
# missed word: Gutenberg™
# missed word: work,
# missed word: (b)
# missed word: alteration,
# missed word: modification,
# missed word: Gutenberg™
# missed word: work,
# missed word: (c)
# missed word: 2.
# missed word: Gutenberg™
# missed word: Gutenberg™
# missed word: obsolete,
# missed word: old,
# missed word: middle-aged
# missed word: computers.
# missed word: life.
# missed word: Gutenberg™’s
# missed word: Gutenberg™
# missed word: come.
# missed word: 2001,
# missed word: Gutenberg™
# missed word: generations.
# missed word: help,
# missed word: 3
# missed word: 4
# missed word: www.gutenberg.org.
# missed word: 3.
# missed word: non-profit
# missed word: 501(c)(3)
# missed word: Service.
# missed word: Foundation’s
# missed word: 64-6221541.
# missed word: U.S.
# missed word: state’s
# missed word: laws.
# missed word: Foundation’s
# missed word: 809
# missed word: 1500
# missed word: West,
# missed word: City,
# missed word: UT
# missed word: 84116,
# missed word: (801)
# missed word: 596-1887.
# missed word: Foundation’s
# missed word: www.gutenberg.org/contact
# missed word: 4.
# missed word: Gutenberg™
# missed word: machine-readable
# missed word: equipment.
# missed word: ($1
# missed word: $5,000)
# missed word: 50
# missed word: States.
# missed word: effort,
# missed word: requirements.
# missed word: compliance.
# missed word: www.gutenberg.org/donate.
# missed word: requirements,
# missed word: donate.
# missed word: accepted,
# missed word: States.
# missed word: U.S.
# missed word: staff.
# missed word: addresses.
# missed word: checks,
# missed word: donations.
# missed word: donate,
# missed word: visit:
# missed word: www.gutenberg.org/donate.
# missed word: 5.
# missed word: Gutenberg™
# missed word: Gutenberg™
# missed word: anyone.
# missed word: years,
# missed word: Gutenberg™
# missed word: eBooks
# missed word: Gutenberg™
# missed word: eBooks
# missed word: editions,
# missed word: U.S.
# missed word: included.
# missed word: Thus,
# missed word: eBooks
# missed word: PG
# missed word: facility:
# missed word: www.gutenberg.org.
# missed word: Gutenberg™,
# missed word: Foundation,
# missed word: eBooks,
# missed word: eBooks.

# %%
print("Phonemes Map:", phonemes_map)
print("Number of Missed Words:", len(missed_words))
print("Number of Words in Phonemes Map:", len(phonemes_map))
# Out:
# {'From': ['F', 'R', 'AH1', 'M'], 'fairest': ['F', 'EH1', 'R', 'IH0', 'S', 'T'], 'creatures': ['K', 'R', 'IY1', 'CH', 'ER0', 'Z'], 'we': ['W', 'IY1'], 'desire': ['D', 'IH0', 'Z', 'AY1', 'ER0'], 'That': ['DH', 'AE1', 'T'], 'thereby': ['DH', 'EH1', 'R', 'B', 'AY1'], 'rose': ['R', 'OW1', 'Z'], 'might': ['M', 'AY1', 'T'], 'never': ['N', 'EH1', 'V', 'ER0'], 'But': ['B', 'AH1', 'T'], 'as': ['AE1', 'Z'], 'the': ['DH', 'AH0'], 'should': ['SH', 'UH1', 'D'], 'by': ['B', 'AY1'], 'time': ['T', 'AY1', 'M'], 'His': ['HH', 'IH1', 'Z'], 'tender': ['T', 'EH1', 'N', 'D', 'ER0'], 'heir': ['EH1', 'R'], 'bear': ['B', 'EH1', 'R'], 'his': ['HH', 'IH1', 'Z'], 'contracted': ['K', 'AA1', 'N', 'T', 'R', 'AE0', 'K', 'T', 'AH0', 'D'], 'to': ['T', 'UW1'], 'thine': ['DH', 'AY1', 'N'], 'own': ['OW1', 'N'], 'bright': ['B', 'R', 'AY1', 'T'], 'thy': ['DH', 'AY1'], 'flame': ['F', 'L', 'EY1', 'M'], 'with': ['W', 'IH1', 'DH'], 'Making': ['M', 'EY1', 'K', 'IH0', 'NG'], 'a': ['AH0'], 'famine': ['F', 'AE1', 'M', 'AH0', 'N'], 'where': ['W', 'EH1', 'R'], 'abundance': ['AH0', 'B', 'AH1', 'N', 'D', 'AH0', 'N', 'S'], 'sweet': ['S', 'W', 'IY1', 'T'], 'self': ['S', 'EH1', 'L', 'F'], 'too': ['T', 'UW1'], 'Thou': ['DH', 'AW1'], 'that': ['DH', 'AE1', 'T'], 'art': ['AA1', 'R', 'T'], 'now': ['N', 'AW1'], 'fresh': ['F', 'R', 'EH1', 'SH'], 'And': ['AH0', 'N', 'D'], 'only': ['OW1', 'N', 'L', 'IY0'], 'herald': ['HH', 'EH1', 'R', 'AH0', 'L', 'D'], 'gaudy': ['G', 'AO1', 'D', 'IY0'], 'Within': ['W', 'IH0', 'DH', 'IH1', 'N'], 'bud': ['B', 'AH1', 'D'], 'waste': ['W', 'EY1', 'S', 'T'], 'in': ['IH0', 'N'], 'Pity': ['P', 'IH1', 'T', 'IY0'], 'or': ['AO1', 'R'], 'else': ['EH1', 'L', 'S'], 'this': ['DH', 'IH1', 'S'], 'To': ['T', 'UW1'], 'eat': ['IY1', 'T'], 'grave': ['G', 'R', 'EY1', 'V'], 'and': ['AH0', 'N', 'D'], 'When': ['W', 'EH1', 'N'], 'forty': ['F', 'AO1', 'R', 'T', 'IY0'], 'winters': ['W', 'IH1', 'N', 'T', 'ER0', 'Z'], 'shall': ['SH', 'AE1', 'L'], 'besiege': ['B', 'IH0', 'S', 'IY1', 'JH'], 'dig': ['D', 'IH1', 'G'], 'deep': ['D', 'IY1', 'P'], 'trenches': ['T', 'R', 'EH1', 'N', 'CH', 'IH0', 'Z'], 'Thy': ['DH', 'AY1'], 'proud': ['P', 'R', 'AW1', 'D'], 'livery': ['L', 'IH1', 'V', 'ER0', 'IY0'], 'so': ['S', 'OW1'], 'gazed': ['G', 'EY1', 'Z', 'D'], 'on': ['AA1', 'N'], 'Will': ['W', 'IH1', 'L'], 'be': ['B', 'IY1'], 'weed': ['W', 'IY1', 'D'], 'of': ['AH1', 'V'], 'small': ['S', 'M', 'AO1', 'L'], 'worth': ['W', 'ER1', 'TH'], 'Then': ['DH', 'EH1', 'N'], 'being': ['B', 'IY1', 'IH0', 'NG'], 'all': ['AO1', 'L'], 'beauty': ['B', 'Y', 'UW1', 'T', 'IY0'], 'Where': ['W', 'EH1', 'R'], 'treasure': ['T', 'R', 'EH1', 'ZH', 'ER0'], 'lusty': ['L', 'AH1', 'S', 'T', 'IY0'], 'within': ['W', 'IH0', 'DH', 'IH1', 'N'], 'sunken': ['S', 'AH1', 'NG', 'K', 'AH0', 'N'], 'Were': ['W', 'ER0'], 'an': ['AE1', 'N'], 'How': ['HH', 'AW1'], 'much': ['M', 'AH1', 'CH'], 'more': ['M', 'AO1', 'R'], 'praise': ['P', 'R', 'EY1', 'Z'], 'If': ['IH1', 'F'], 'thou': ['DH', 'AW1'], 'answer': ['AE1', 'N', 'S', 'ER0'], 'fair': ['F', 'EH1', 'R'], 'child': ['CH', 'AY1', 'L', 'D'], 'mine': ['M', 'AY1', 'N'], 'Shall': ['SH', 'AE1', 'L'], 'sum': ['S', 'AH1', 'M'], 'my': ['M', 'AY1'], 'make': ['M', 'EY1', 'K'], 'old': ['OW1', 'L', 'D'], 'Proving': ['P', 'R', 'UW1', 'V', 'IH0', 'NG'], 'succession': ['S', 'AH0', 'K', 'S', 'EH1', 'SH', 'AH0', 'N'], 'This': ['DH', 'IH1', 'S'], 'were': ['W', 'ER0'], 'new': ['N', 'UW1'], 'made': ['M', 'EY1', 'D'], 'when': ['W', 'EH1', 'N'], 'see': ['S', 'IY1'], 'blood': ['B', 'L', 'AH1', 'D'], 'warm': ['W', 'AO1', 'R', 'M'], 'it': ['IH1', 'T'], 'Look': ['L', 'UH1', 'K'], 'glass': ['G', 'L', 'AE1', 'S'], 'tell': ['T', 'EH1', 'L'], 'face': ['F', 'EY1', 'S'], 'Now': ['N', 'AW1'], 'is': ['IH1', 'Z'], 'form': ['F', 'AO1', 'R', 'M'], 'Whose': ['HH', 'UW1', 'Z'], 'repair': ['R', 'IH0', 'P', 'EH1', 'R'], 'if': ['IH1', 'F'], 'not': ['N', 'AA1', 'T'], 'dost': ['D', 'AA1', 'S', 'T'], 'beguile': ['B', 'IH0', 'G', 'AY1', 'L'], 'some': ['S', 'AH1', 'M'], 'For': ['F', 'AO1', 'R'], 'she': ['SH', 'IY1'], 'whose': ['HH', 'UW1', 'Z'], 'wom ...
# 4103
# 2832

# %% [markdown]
# ### saving the trained model to a file

# %%
# Save the trained model to a file
model.save("trained_text_gen_drop_model-1.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
